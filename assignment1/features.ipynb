# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM
import time

learning_rates = [5e-6, 5e-5,1e-6]
regularization_strengths = [5e1, 2e2, 5e2]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

NUM_ITERS = 2000

for lr in learning_rates:
     for reg in regularization_strengths:
         model = LinearSVM()
         tic = time.time()
         loss_hist = model.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                      num_iters=NUM_ITERS, batch_size = 400, verbose=True)
         toc = time.time()
         print('That took %fs' % (toc - tic))
         y_train_pred = model.predict(X_train_feats)
         train_acc = np.mean(y_train_pred == y_train)
         y_val_pred = model.predict(X_val_feats)
         val_acc = np.mean(y_val_pred == y_val)
         results[(lr,reg)] = (train_acc, val_acc)
         if best_val < val_acc:
            best_val = val_acc
            best_svm = model
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 2000: loss 9.076379
# iteration 100 / 2000: loss 9.041943
# iteration 200 / 2000: loss 9.005758
# iteration 300 / 2000: loss 8.974857
# iteration 400 / 2000: loss 8.937229
# iteration 500 / 2000: loss 8.912975
# iteration 600 / 2000: loss 8.887871
# iteration 700 / 2000: loss 8.854075
# iteration 800 / 2000: loss 8.840195
# iteration 900 / 2000: loss 8.808873
# iteration 1000 / 2000: loss 8.795515
# iteration 1100 / 2000: loss 8.805022
# iteration 1200 / 2000: loss 8.788046
# iteration 1300 / 2000: loss 8.773468
# iteration 1400 / 2000: loss 8.782447
# iteration 1500 / 2000: loss 8.773998
# iteration 1600 / 2000: loss 8.760909
# iteration 1700 / 2000: loss 8.739234
# iteration 1800 / 2000: loss 8.720894
# iteration 1900 / 2000: loss 8.707877
# That took 17.090268s
# iteration 0 / 2000: loss 9.292427
# iteration 100 / 2000: loss 9.169814
# iteration 200 / 2000: loss 9.079486
# iteration 300 / 2000: loss 9.038499
# iteration 400 / 2000: loss 8.995205
# iteration 500 / 2000: loss 8.962423
# iteration 600 / 2000: loss 8.947787
# iteration 700 / 2000: loss 8.935099
# iteration 800 / 2000: loss 8.924313
# iteration 900 / 2000: loss 8.917072
# iteration 1000 / 2000: loss 8.924584
# iteration 1100 / 2000: loss 8.919007
# iteration 1200 / 2000: loss 8.915174
# iteration 1300 / 2000: loss 8.910606
# iteration 1400 / 2000: loss 8.929905
# iteration 1500 / 2000: loss 8.902726
# iteration 1600 / 2000: loss 8.923418
# iteration 1700 / 2000: loss 8.905410
# iteration 1800 / 2000: loss 8.914658
# iteration 1900 / 2000: loss 8.920772
# That took 17.563908s
# iteration 0 / 2000: loss 9.734953
# iteration 100 / 2000: loss 9.244722
# iteration 200 / 2000: loss 9.069030
# iteration 300 / 2000: loss 9.000186
# iteration 400 / 2000: loss 8.979427
# iteration 500 / 2000: loss 8.973268
# iteration 600 / 2000: loss 8.962555
# iteration 700 / 2000: loss 8.968767
# iteration 800 / 2000: loss 8.965796
# iteration 900 / 2000: loss 8.965658
# iteration 1000 / 2000: loss 8.962878
# iteration 1100 / 2000: loss 8.968684
# iteration 1200 / 2000: loss 8.957391
# iteration 1300 / 2000: loss 8.958393
# iteration 1400 / 2000: loss 8.959127
# iteration 1500 / 2000: loss 8.961538
# iteration 1600 / 2000: loss 8.967544
# iteration 1700 / 2000: loss 8.968501
# iteration 1800 / 2000: loss 8.963566
# iteration 1900 / 2000: loss 8.962444
# That took 14.447145s
# iteration 0 / 2000: loss 9.072640
# iteration 100 / 2000: loss 8.819691
# iteration 200 / 2000: loss 8.649290
# iteration 300 / 2000: loss 8.680299
# iteration 400 / 2000: loss 8.673942
# iteration 500 / 2000: loss 8.701064
# iteration 600 / 2000: loss 8.726156
# iteration 700 / 2000: loss 8.654213
# iteration 800 / 2000: loss 8.640540
# iteration 900 / 2000: loss 8.592359
# iteration 1000 / 2000: loss 8.674207
# iteration 1100 / 2000: loss 8.647423
# iteration 1200 / 2000: loss 8.630192
# iteration 1300 / 2000: loss 8.626738
# iteration 1400 / 2000: loss 8.601888
# iteration 1500 / 2000: loss 8.625235
# iteration 1600 / 2000: loss 8.665502
# iteration 1700 / 2000: loss 8.637398
# iteration 1800 / 2000: loss 8.699498
# iteration 1900 / 2000: loss 8.680312
# That took 12.899504s
# iteration 0 / 2000: loss 9.273027
# iteration 100 / 2000: loss 8.917781
# iteration 200 / 2000: loss 8.914644
# iteration 300 / 2000: loss 8.901700
# iteration 400 / 2000: loss 8.911235
# iteration 500 / 2000: loss 8.917141
# iteration 600 / 2000: loss 8.926234
# iteration 700 / 2000: loss 8.906921
# iteration 800 / 2000: loss 8.907916
# iteration 900 / 2000: loss 8.912099
# iteration 1000 / 2000: loss 8.907132
# iteration 1100 / 2000: loss 8.912562
# iteration 1200 / 2000: loss 8.917230
# iteration 1300 / 2000: loss 8.910268
# iteration 1400 / 2000: loss 8.911869
# iteration 1500 / 2000: loss 8.908421
# iteration 1600 / 2000: loss 8.917642
# iteration 1700 / 2000: loss 8.914231
# iteration 1800 / 2000: loss 8.912215
# iteration 1900 / 2000: loss 8.907419
# That took 13.312390s
# iteration 0 / 2000: loss 9.746615
# iteration 100 / 2000: loss 8.964905
# iteration 200 / 2000: loss 8.964120
# iteration 300 / 2000: loss 8.962975
# iteration 400 / 2000: loss 8.965250
# iteration 500 / 2000: loss 8.963770
# iteration 600 / 2000: loss 8.963638
# iteration 700 / 2000: loss 8.967037
# iteration 800 / 2000: loss 8.959814
# iteration 900 / 2000: loss 8.968080
# iteration 1000 / 2000: loss 8.968109
# iteration 1100 / 2000: loss 8.960121
# iteration 1200 / 2000: loss 8.971691
# iteration 1300 / 2000: loss 8.964844
# iteration 1400 / 2000: loss 8.959989
# iteration 1500 / 2000: loss 8.970108
# iteration 1600 / 2000: loss 8.966029
# iteration 1700 / 2000: loss 8.965936
# iteration 1800 / 2000: loss 8.964877
# iteration 1900 / 2000: loss 8.963168
# That took 13.995573s
# iteration 0 / 2000: loss 9.073299
# iteration 100 / 2000: loss 9.074717
# iteration 200 / 2000: loss 9.067766
# iteration 300 / 2000: loss 9.051005
# iteration 400 / 2000: loss 9.033048
# iteration 500 / 2000: loss 9.051539
# iteration 600 / 2000: loss 9.039952
# iteration 700 / 2000: loss 9.029696
# iteration 800 / 2000: loss 9.012093
# iteration 900 / 2000: loss 9.010374
# iteration 1000 / 2000: loss 8.996223
# iteration 1100 / 2000: loss 8.991584
# iteration 1200 / 2000: loss 8.986978
# iteration 1300 / 2000: loss 8.977531
# iteration 1400 / 2000: loss 8.967272
# iteration 1500 / 2000: loss 8.969792
# iteration 1600 / 2000: loss 8.956083
# iteration 1700 / 2000: loss 8.953344
# iteration 1800 / 2000: loss 8.940474
# iteration 1900 / 2000: loss 8.945587
# That took 15.094634s
# iteration 0 / 2000: loss 9.331526
# iteration 100 / 2000: loss 9.310298
# iteration 200 / 2000: loss 9.276931
# iteration 300 / 2000: loss 9.246347
# iteration 400 / 2000: loss 9.218221
# iteration 500 / 2000: loss 9.210769
# iteration 600 / 2000: loss 9.174087
# iteration 700 / 2000: loss 9.152407
# iteration 800 / 2000: loss 9.140238
# iteration 900 / 2000: loss 9.129419
# iteration 1000 / 2000: loss 9.099687
# iteration 1100 / 2000: loss 9.100603
# iteration 1200 / 2000: loss 9.076597
# iteration 1300 / 2000: loss 9.067607
# iteration 1400 / 2000: loss 9.046167
# iteration 1500 / 2000: loss 9.042597
# iteration 1600 / 2000: loss 9.029781
# iteration 1700 / 2000: loss 9.023980
# iteration 1800 / 2000: loss 9.011065
# iteration 1900 / 2000: loss 8.996817
# That took 15.592539s
# iteration 0 / 2000: loss 9.791468
# iteration 100 / 2000: loss 9.640613
# iteration 200 / 2000: loss 9.518629
# iteration 300 / 2000: loss 9.410249
# iteration 400 / 2000: loss 9.342145
# iteration 500 / 2000: loss 9.264862
# iteration 600 / 2000: loss 9.214197
# iteration 700 / 2000: loss 9.170661
# iteration 800 / 2000: loss 9.132194
# iteration 900 / 2000: loss 9.103286
# iteration 1000 / 2000: loss 9.077290
# iteration 1100 / 2000: loss 9.057593
# iteration 1200 / 2000: loss 9.035894
# iteration 1300 / 2000: loss 9.028429
# iteration 1400 / 2000: loss 9.008471
# iteration 1500 / 2000: loss 9.007356
# iteration 1600 / 2000: loss 9.002130
# iteration 1700 / 2000: loss 8.988118
# iteration 1800 / 2000: loss 8.988851
# iteration 1900 / 2000: loss 8.985738
# That took 15.139662s
# lr 1.000000e-06 reg 5.000000e+01 train accuracy: 0.280673 val accuracy: 0.280000
# lr 1.000000e-06 reg 2.000000e+02 train accuracy: 0.339449 val accuracy: 0.340000
# lr 1.000000e-06 reg 5.000000e+02 train accuracy: 0.391694 val accuracy: 0.394000
# lr 5.000000e-06 reg 5.000000e+01 train accuracy: 0.413367 val accuracy: 0.416000
# lr 5.000000e-06 reg 2.000000e+02 train accuracy: 0.416122 val accuracy: 0.419000
# lr 5.000000e-06 reg 5.000000e+02 train accuracy: 0.416571 val accuracy: 0.419000
# lr 5.000000e-05 reg 5.000000e+01 train accuracy: 0.416796 val accuracy: 0.422000
# lr 5.000000e-05 reg 2.000000e+02 train accuracy: 0.419714 val accuracy: 0.423000
# lr 5.000000e-05 reg 5.000000e+02 train accuracy: 0.418531 val accuracy: 0.421000
# best validation accuracy achieved during cross-validation: 0.423000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.42

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$由于抽取的手工特征是HOG和颜色直方图，上面分错的大多都是物体轮廓相似，或者颜色，背景相似的。

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10
NUM_ITERS = 2000
best_net = None
best_acc = 0
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

learning_rates = [1e-1,5e-1, 1e-2]
learning_rate_decays = [0.95, 0.99]
regs = [3e-4,1e-3,3e-3]
#batch_sizes=[200,400]
for lr in learning_rates:
        for lr_deacy in learning_rate_decays:
            for reg in regs:
                # Train the network
                net = TwoLayerNet(input_dim, hidden_dim, num_classes)
                stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                       num_iters=NUM_ITERS, batch_size=200,
                       learning_rate=lr, learning_rate_decay=lr_deacy,
                       reg=reg, verbose=True)
            # Predict on the validation set
                val_acc = (net.predict(X_val_feats) == y_val).mean()
                if best_acc < val_acc:
                   best_acc = val_acc
                   best_net = net
                print('lr=%f, lr_deacy=%f, reg=%f,Validation accuracy=%f'\
                      %(lr, lr_deacy, reg, val_acc))
print('best_acc=%f'%(best_acc))

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.301762
# iteration 200 / 2000: loss 2.141806
# iteration 300 / 2000: loss 1.774299
# iteration 400 / 2000: loss 1.542557
# iteration 500 / 2000: loss 1.442635
# iteration 600 / 2000: loss 1.534318
# iteration 700 / 2000: loss 1.452495
# iteration 800 / 2000: loss 1.517254
# iteration 900 / 2000: loss 1.237975
# iteration 1000 / 2000: loss 1.352942
# iteration 1100 / 2000: loss 1.340184
# iteration 1200 / 2000: loss 1.378499
# iteration 1300 / 2000: loss 1.315878
# iteration 1400 / 2000: loss 1.383713
# iteration 1500 / 2000: loss 1.241585
# iteration 1600 / 2000: loss 1.314249
# iteration 1700 / 2000: loss 1.395662
# iteration 1800 / 2000: loss 1.313304
# iteration 1900 / 2000: loss 1.248724
# lr=0.100000, lr_deacy=0.950000, reg=0.000300,Validation accuracy=0.542000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302183
# iteration 200 / 2000: loss 2.151180
# iteration 300 / 2000: loss 1.795195
# iteration 400 / 2000: loss 1.587861
# iteration 500 / 2000: loss 1.563635
# iteration 600 / 2000: loss 1.568616
# iteration 700 / 2000: loss 1.378321
# iteration 800 / 2000: loss 1.385224
# iteration 900 / 2000: loss 1.465650
# iteration 1000 / 2000: loss 1.358747
# iteration 1100 / 2000: loss 1.403980
# iteration 1200 / 2000: loss 1.234980
# iteration 1300 / 2000: loss 1.336327
# iteration 1400 / 2000: loss 1.239992
# iteration 1500 / 2000: loss 1.386203
# iteration 1600 / 2000: loss 1.358229
# iteration 1700 / 2000: loss 1.216079
# iteration 1800 / 2000: loss 1.354646
# iteration 1900 / 2000: loss 1.458167
# lr=0.100000, lr_deacy=0.950000, reg=0.001000,Validation accuracy=0.537000
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.301142
# iteration 200 / 2000: loss 2.119507
# iteration 300 / 2000: loss 1.819543
# iteration 400 / 2000: loss 1.736711
# iteration 500 / 2000: loss 1.439028
# iteration 600 / 2000: loss 1.481914
# iteration 700 / 2000: loss 1.613093
# iteration 800 / 2000: loss 1.504145
# iteration 900 / 2000: loss 1.398203
# iteration 1000 / 2000: loss 1.448036
# iteration 1100 / 2000: loss 1.472501
# iteration 1200 / 2000: loss 1.421265
# iteration 1300 / 2000: loss 1.362840
# iteration 1400 / 2000: loss 1.543158
# iteration 1500 / 2000: loss 1.428822
# iteration 1600 / 2000: loss 1.378066
# iteration 1700 / 2000: loss 1.312908
# iteration 1800 / 2000: loss 1.358679
# iteration 1900 / 2000: loss 1.361447
# lr=0.100000, lr_deacy=0.950000, reg=0.003000,Validation accuracy=0.529000
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302133
# iteration 200 / 2000: loss 2.129201
# iteration 300 / 2000: loss 1.847235
# iteration 400 / 2000: loss 1.519548
# iteration 500 / 2000: loss 1.420468
# iteration 600 / 2000: loss 1.469745
# iteration 700 / 2000: loss 1.411755
# iteration 800 / 2000: loss 1.380977
# iteration 900 / 2000: loss 1.358567
# iteration 1000 / 2000: loss 1.320130
# iteration 1100 / 2000: loss 1.307469
# iteration 1200 / 2000: loss 1.371651
# iteration 1300 / 2000: loss 1.384779
# iteration 1400 / 2000: loss 1.280018
# iteration 1500 / 2000: loss 1.368235
# iteration 1600 / 2000: loss 1.169328
# iteration 1700 / 2000: loss 1.202252
# iteration 1800 / 2000: loss 1.215760
# iteration 1900 / 2000: loss 1.314991
# lr=0.100000, lr_deacy=0.990000, reg=0.000300,Validation accuracy=0.543000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.301082
# iteration 200 / 2000: loss 2.127081
# iteration 300 / 2000: loss 1.782318
# iteration 400 / 2000: loss 1.473790
# iteration 500 / 2000: loss 1.533715
# iteration 600 / 2000: loss 1.594325
# iteration 700 / 2000: loss 1.455332
# iteration 800 / 2000: loss 1.477573
# iteration 900 / 2000: loss 1.459794
# iteration 1000 / 2000: loss 1.375233
# iteration 1100 / 2000: loss 1.188886
# iteration 1200 / 2000: loss 1.332819
# iteration 1300 / 2000: loss 1.286667
# iteration 1400 / 2000: loss 1.349135
# iteration 1500 / 2000: loss 1.292981
# iteration 1600 / 2000: loss 1.260178
# iteration 1700 / 2000: loss 1.297626
# iteration 1800 / 2000: loss 1.358303
# iteration 1900 / 2000: loss 1.278623
# lr=0.100000, lr_deacy=0.990000, reg=0.001000,Validation accuracy=0.543000
# iteration 0 / 2000: loss 2.302588
# iteration 100 / 2000: loss 2.300539
# iteration 200 / 2000: loss 2.114776
# iteration 300 / 2000: loss 1.860883
# iteration 400 / 2000: loss 1.649743
# iteration 500 / 2000: loss 1.577310
# iteration 600 / 2000: loss 1.367405
# iteration 700 / 2000: loss 1.443086
# iteration 800 / 2000: loss 1.434862
# iteration 900 / 2000: loss 1.377431
# iteration 1000 / 2000: loss 1.474204
# iteration 1100 / 2000: loss 1.450376
# iteration 1200 / 2000: loss 1.366701
# iteration 1300 / 2000: loss 1.428544
# iteration 1400 / 2000: loss 1.416846
# iteration 1500 / 2000: loss 1.435120
# iteration 1600 / 2000: loss 1.460968
# iteration 1700 / 2000: loss 1.271598
# iteration 1800 / 2000: loss 1.436848
# iteration 1900 / 2000: loss 1.465766
# lr=0.100000, lr_deacy=0.990000, reg=0.003000,Validation accuracy=0.530000
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 1.622100
# iteration 200 / 2000: loss 1.363435
# iteration 300 / 2000: loss 1.321059
# iteration 400 / 2000: loss 1.296329
# iteration 500 / 2000: loss 1.275589
# iteration 600 / 2000: loss 1.155178
# iteration 700 / 2000: loss 1.150941
# iteration 800 / 2000: loss 1.056109
# iteration 900 / 2000: loss 1.131156
# iteration 1000 / 2000: loss 1.128237
# iteration 1100 / 2000: loss 1.008902
# iteration 1200 / 2000: loss 1.110910
# iteration 1300 / 2000: loss 1.204596
# iteration 1400 / 2000: loss 1.041610
# iteration 1500 / 2000: loss 0.853802
# iteration 1600 / 2000: loss 1.114404
# iteration 1700 / 2000: loss 0.984819
# iteration 1800 / 2000: loss 0.994626
# iteration 1900 / 2000: loss 0.889873
# lr=0.500000, lr_deacy=0.950000, reg=0.000300,Validation accuracy=0.596000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 1.612673
# iteration 200 / 2000: loss 1.500446
# iteration 300 / 2000: loss 1.265668
# iteration 400 / 2000: loss 1.457293
# iteration 500 / 2000: loss 1.348357
# iteration 600 / 2000: loss 1.285410
# iteration 700 / 2000: loss 1.200584
# iteration 800 / 2000: loss 1.221233
# iteration 900 / 2000: loss 1.301980
# iteration 1000 / 2000: loss 1.170356
# iteration 1100 / 2000: loss 1.147995
# iteration 1200 / 2000: loss 1.148728
# iteration 1300 / 2000: loss 1.101257
# iteration 1400 / 2000: loss 1.154372
# iteration 1500 / 2000: loss 1.097472
# iteration 1600 / 2000: loss 1.231205
# iteration 1700 / 2000: loss 1.249811
# iteration 1800 / 2000: loss 1.060655
# iteration 1900 / 2000: loss 1.080107
# lr=0.500000, lr_deacy=0.950000, reg=0.001000,Validation accuracy=0.590000
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 1.521649
# iteration 200 / 2000: loss 1.498582
# iteration 300 / 2000: loss 1.493564
# iteration 400 / 2000: loss 1.468613
# iteration 500 / 2000: loss 1.351131
# iteration 600 / 2000: loss 1.399818
# iteration 700 / 2000: loss 1.436323
# iteration 800 / 2000: loss 1.544825
# iteration 900 / 2000: loss 1.427047
# iteration 1000 / 2000: loss 1.284397
# iteration 1100 / 2000: loss 1.212378
# iteration 1200 / 2000: loss 1.387597
# iteration 1300 / 2000: loss 1.375672
# iteration 1400 / 2000: loss 1.383479
# iteration 1500 / 2000: loss 1.342254
# iteration 1600 / 2000: loss 1.406758
# iteration 1700 / 2000: loss 1.389006
# iteration 1800 / 2000: loss 1.310614
# iteration 1900 / 2000: loss 1.362827
# lr=0.500000, lr_deacy=0.950000, reg=0.003000,Validation accuracy=0.577000
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 1.465597
# iteration 200 / 2000: loss 1.370918
# iteration 300 / 2000: loss 1.432732
# iteration 400 / 2000: loss 1.332328
# iteration 500 / 2000: loss 1.242574
# iteration 600 / 2000: loss 1.121935
# iteration 700 / 2000: loss 1.308298
# iteration 800 / 2000: loss 1.110178
# iteration 900 / 2000: loss 1.036884
# iteration 1000 / 2000: loss 1.241483
# iteration 1100 / 2000: loss 1.053573
# iteration 1200 / 2000: loss 1.026950
# iteration 1300 / 2000: loss 0.900540
# iteration 1400 / 2000: loss 1.137297
# iteration 1500 / 2000: loss 1.000953
# iteration 1600 / 2000: loss 0.993893
# iteration 1700 / 2000: loss 1.037618
# iteration 1800 / 2000: loss 0.958266
# iteration 1900 / 2000: loss 0.971981
# lr=0.500000, lr_deacy=0.990000, reg=0.000300,Validation accuracy=0.585000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 1.442355
# iteration 200 / 2000: loss 1.537118
# iteration 300 / 2000: loss 1.298133
# iteration 400 / 2000: loss 1.286696
# iteration 500 / 2000: loss 1.327570
# iteration 600 / 2000: loss 1.320504
# iteration 700 / 2000: loss 1.108558
# iteration 800 / 2000: loss 1.121415
# iteration 900 / 2000: loss 1.250825
# iteration 1000 / 2000: loss 1.262097
# iteration 1100 / 2000: loss 1.093305
# iteration 1200 / 2000: loss 1.200626
# iteration 1300 / 2000: loss 1.090899
# iteration 1400 / 2000: loss 1.156319
# iteration 1500 / 2000: loss 1.124686
# iteration 1600 / 2000: loss 1.259910
# iteration 1700 / 2000: loss 1.083745
# iteration 1800 / 2000: loss 1.130903
# iteration 1900 / 2000: loss 1.086007
# lr=0.500000, lr_deacy=0.990000, reg=0.001000,Validation accuracy=0.572000
# iteration 0 / 2000: loss 2.302588
# iteration 100 / 2000: loss 1.716783
# iteration 200 / 2000: loss 1.377129
# iteration 300 / 2000: loss 1.424481
# iteration 400 / 2000: loss 1.464476
# iteration 500 / 2000: loss 1.475744
# iteration 600 / 2000: loss 1.488936
# iteration 700 / 2000: loss 1.346356
# iteration 800 / 2000: loss 1.421739
# iteration 900 / 2000: loss 1.410831
# iteration 1000 / 2000: loss 1.364256
# iteration 1100 / 2000: loss 1.359874
# iteration 1200 / 2000: loss 1.267383
# iteration 1300 / 2000: loss 1.377936
# iteration 1400 / 2000: loss 1.561339
# iteration 1500 / 2000: loss 1.346768
# iteration 1600 / 2000: loss 1.321111
# iteration 1700 / 2000: loss 1.315786
# iteration 1800 / 2000: loss 1.396931
# iteration 1900 / 2000: loss 1.318667
# lr=0.500000, lr_deacy=0.990000, reg=0.003000,Validation accuracy=0.559000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302676
# iteration 200 / 2000: loss 2.302678
# iteration 300 / 2000: loss 2.302292
# iteration 400 / 2000: loss 2.302513
# iteration 500 / 2000: loss 2.302540
# iteration 600 / 2000: loss 2.302490
# iteration 700 / 2000: loss 2.302850
# iteration 800 / 2000: loss 2.302050
# iteration 900 / 2000: loss 2.303123
# iteration 1000 / 2000: loss 2.302040
# iteration 1100 / 2000: loss 2.302001
# iteration 1200 / 2000: loss 2.302070
# iteration 1300 / 2000: loss 2.301427
# iteration 1400 / 2000: loss 2.299809
# iteration 1500 / 2000: loss 2.299032
# iteration 1600 / 2000: loss 2.296572
# iteration 1700 / 2000: loss 2.291531
# iteration 1800 / 2000: loss 2.284608
# iteration 1900 / 2000: loss 2.277210
# lr=0.010000, lr_deacy=0.950000, reg=0.000300,Validation accuracy=0.211000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302635
# iteration 200 / 2000: loss 2.302419
# iteration 300 / 2000: loss 2.302558
# iteration 400 / 2000: loss 2.302275
# iteration 500 / 2000: loss 2.302657
# iteration 600 / 2000: loss 2.302680
# iteration 700 / 2000: loss 2.302220
# iteration 800 / 2000: loss 2.302406
# iteration 900 / 2000: loss 2.302461
# iteration 1000 / 2000: loss 2.301718
# iteration 1100 / 2000: loss 2.302276
# iteration 1200 / 2000: loss 2.301926
# iteration 1300 / 2000: loss 2.300786
# iteration 1400 / 2000: loss 2.299979
# iteration 1500 / 2000: loss 2.298542
# iteration 1600 / 2000: loss 2.297898
# iteration 1700 / 2000: loss 2.292492
# iteration 1800 / 2000: loss 2.284942
# iteration 1900 / 2000: loss 2.280847
# lr=0.010000, lr_deacy=0.950000, reg=0.001000,Validation accuracy=0.222000
# iteration 0 / 2000: loss 2.302588
# iteration 100 / 2000: loss 2.302304
# iteration 200 / 2000: loss 2.302438
# iteration 300 / 2000: loss 2.302627
# iteration 400 / 2000: loss 2.302592
# iteration 500 / 2000: loss 2.302504
# iteration 600 / 2000: loss 2.302673
# iteration 700 / 2000: loss 2.302434
# iteration 800 / 2000: loss 2.302513
# iteration 900 / 2000: loss 2.301877
# iteration 1000 / 2000: loss 2.302396
# iteration 1100 / 2000: loss 2.301797
# iteration 1200 / 2000: loss 2.301434
# iteration 1300 / 2000: loss 2.301166
# iteration 1400 / 2000: loss 2.300326
# iteration 1500 / 2000: loss 2.298024
# iteration 1600 / 2000: loss 2.295529
# iteration 1700 / 2000: loss 2.292700
# iteration 1800 / 2000: loss 2.284118
# iteration 1900 / 2000: loss 2.272112
# lr=0.010000, lr_deacy=0.950000, reg=0.003000,Validation accuracy=0.229000
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302408
# iteration 200 / 2000: loss 2.303055
# iteration 300 / 2000: loss 2.302326
# iteration 400 / 2000: loss 2.302991
# iteration 500 / 2000: loss 2.302463
# iteration 600 / 2000: loss 2.302530
# iteration 700 / 2000: loss 2.302526
# iteration 800 / 2000: loss 2.302021
# iteration 900 / 2000: loss 2.302855
# iteration 1000 / 2000: loss 2.301830
# iteration 1100 / 2000: loss 2.301118
# iteration 1200 / 2000: loss 2.300623
# iteration 1300 / 2000: loss 2.297286
# iteration 1400 / 2000: loss 2.290484
# iteration 1500 / 2000: loss 2.279249
# iteration 1600 / 2000: loss 2.269423
# iteration 1700 / 2000: loss 2.224144
# iteration 1800 / 2000: loss 2.212443
# iteration 1900 / 2000: loss 2.150748
# lr=0.010000, lr_deacy=0.990000, reg=0.000300,Validation accuracy=0.233000
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302697
# iteration 200 / 2000: loss 2.302524
# iteration 300 / 2000: loss 2.302628
# iteration 400 / 2000: loss 2.302495
# iteration 500 / 2000: loss 2.302674
# iteration 600 / 2000: loss 2.302286
# iteration 700 / 2000: loss 2.302252
# iteration 800 / 2000: loss 2.302472
# iteration 900 / 2000: loss 2.301807
# iteration 1000 / 2000: loss 2.301634
# iteration 1100 / 2000: loss 2.300803
# iteration 1200 / 2000: loss 2.300103
# iteration 1300 / 2000: loss 2.298230
# iteration 1400 / 2000: loss 2.295457
# iteration 1500 / 2000: loss 2.291763
# iteration 1600 / 2000: loss 2.278014
# iteration 1700 / 2000: loss 2.244159
# iteration 1800 / 2000: loss 2.214156
# iteration 1900 / 2000: loss 2.180515
# lr=0.010000, lr_deacy=0.990000, reg=0.001000,Validation accuracy=0.242000
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302582
# iteration 200 / 2000: loss 2.302807
# iteration 300 / 2000: loss 2.302809
# iteration 400 / 2000: loss 2.302397
# iteration 500 / 2000: loss 2.302496
# iteration 600 / 2000: loss 2.302613
# iteration 700 / 2000: loss 2.302167
# iteration 800 / 2000: loss 2.302219
# iteration 900 / 2000: loss 2.302607
# iteration 1000 / 2000: loss 2.301800
# iteration 1100 / 2000: loss 2.301042
# iteration 1200 / 2000: loss 2.300390
# iteration 1300 / 2000: loss 2.299177
# iteration 1400 / 2000: loss 2.291954
# iteration 1500 / 2000: loss 2.283073
# iteration 1600 / 2000: loss 2.278554
# iteration 1700 / 2000: loss 2.231760
# iteration 1800 / 2000: loss 2.200433
# iteration 1900 / 2000: loss 2.195415
# lr=0.010000, lr_deacy=0.990000, reg=0.003000,Validation accuracy=0.232000
# best_acc=0.596000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.564

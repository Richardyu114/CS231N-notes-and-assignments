# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720496109664e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.794120407794253e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865070e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.02.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01714960793873204

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (52% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
best_acc = 0
input_size = 32 * 32 * 3
hidden_sizes = [80, 100, 150,200]
learning_rates = [1e-3, 1e-4, 1e-5]
learning_rate_decays = [0.95, 0.90]
regs = [0.15, 0.25, 0.4]
#batch_sizes=[200,400]
NUM_ITERS = 2000
num_classes = 10
for hidden_size in hidden_sizes:
    for lr in learning_rates:
        for lr_deacy in learning_rate_decays:
            for reg in regs:
                # Train the network
                net = TwoLayerNet(input_size, hidden_size, num_classes)
                stats = net.train(X_train, y_train, X_val, y_val,
                       num_iters=NUM_ITERS, batch_size=200,
                       learning_rate=lr, learning_rate_decay=lr_deacy,
                       reg=reg, verbose=True)
            # Predict on the validation set
                val_acc = (net.predict(X_val) == y_val).mean()
                if best_acc < val_acc:
                   best_acc = val_acc
                   best_net = net
                print('hidden_size=%d, lr=%f, lr_deacy=%f, reg=%f,Validation accuracy=%f'\
                      %(hidden_size, lr, lr_deacy, reg, val_acc))
print('best_acc=%f'%(best_acc))
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# iteration 0 / 2000: loss 2.302956
# iteration 100 / 2000: loss 1.886207
# iteration 200 / 2000: loss 1.740863
# iteration 300 / 2000: loss 1.784215
# iteration 400 / 2000: loss 1.454873
# iteration 500 / 2000: loss 1.552536
# iteration 600 / 2000: loss 1.540725
# iteration 700 / 2000: loss 1.401507
# iteration 800 / 2000: loss 1.453141
# iteration 900 / 2000: loss 1.431981
# iteration 1000 / 2000: loss 1.489183
# iteration 1100 / 2000: loss 1.502490
# iteration 1200 / 2000: loss 1.422256
# iteration 1300 / 2000: loss 1.411426
# iteration 1400 / 2000: loss 1.339360
# iteration 1500 / 2000: loss 1.491728
# iteration 1600 / 2000: loss 1.405109
# iteration 1700 / 2000: loss 1.437090
# iteration 1800 / 2000: loss 1.471877
# iteration 1900 / 2000: loss 1.400269
# hidden_size=80, lr=0.001000, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.490000
# iteration 0 / 2000: loss 2.303164
# iteration 100 / 2000: loss 1.894185
# iteration 200 / 2000: loss 1.711093
# iteration 300 / 2000: loss 1.706351
# iteration 400 / 2000: loss 1.587340
# iteration 500 / 2000: loss 1.709947
# iteration 600 / 2000: loss 1.540247
# iteration 700 / 2000: loss 1.503148
# iteration 800 / 2000: loss 1.514791
# iteration 900 / 2000: loss 1.485180
# iteration 1000 / 2000: loss 1.536313
# iteration 1100 / 2000: loss 1.539852
# iteration 1200 / 2000: loss 1.629620
# iteration 1300 / 2000: loss 1.432307
# iteration 1400 / 2000: loss 1.323722
# iteration 1500 / 2000: loss 1.446443
# iteration 1600 / 2000: loss 1.466440
# iteration 1700 / 2000: loss 1.374867
# iteration 1800 / 2000: loss 1.563407
# iteration 1900 / 2000: loss 1.385122
# hidden_size=80, lr=0.001000, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.510000
# iteration 0 / 2000: loss 2.303548
# iteration 100 / 2000: loss 1.948397
# iteration 200 / 2000: loss 1.780371
# iteration 300 / 2000: loss 1.723793
# iteration 400 / 2000: loss 1.591360
# iteration 500 / 2000: loss 1.663808
# iteration 600 / 2000: loss 1.519584
# iteration 700 / 2000: loss 1.550213
# iteration 800 / 2000: loss 1.572378
# iteration 900 / 2000: loss 1.539619
# iteration 1000 / 2000: loss 1.473996
# iteration 1100 / 2000: loss 1.689425
# iteration 1200 / 2000: loss 1.537566
# iteration 1300 / 2000: loss 1.420228
# iteration 1400 / 2000: loss 1.542363
# iteration 1500 / 2000: loss 1.444091
# iteration 1600 / 2000: loss 1.510796
# iteration 1700 / 2000: loss 1.446963
# iteration 1800 / 2000: loss 1.773816
# iteration 1900 / 2000: loss 1.404800
# hidden_size=80, lr=0.001000, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.505000
# iteration 0 / 2000: loss 2.302970
# iteration 100 / 2000: loss 1.939927
# iteration 200 / 2000: loss 1.772538
# iteration 300 / 2000: loss 1.644725
# iteration 400 / 2000: loss 1.667457
# iteration 500 / 2000: loss 1.584722
# iteration 600 / 2000: loss 1.552188
# iteration 700 / 2000: loss 1.535505
# iteration 800 / 2000: loss 1.525243
# iteration 900 / 2000: loss 1.449704
# iteration 1000 / 2000: loss 1.546042
# iteration 1100 / 2000: loss 1.508329
# iteration 1200 / 2000: loss 1.459083
# iteration 1300 / 2000: loss 1.502680
# iteration 1400 / 2000: loss 1.450565
# iteration 1500 / 2000: loss 1.498426
# iteration 1600 / 2000: loss 1.414587
# iteration 1700 / 2000: loss 1.379093
# iteration 1800 / 2000: loss 1.314891
# iteration 1900 / 2000: loss 1.442571
# hidden_size=80, lr=0.001000, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.497000
# iteration 0 / 2000: loss 2.303208
# iteration 100 / 2000: loss 1.980815
# iteration 200 / 2000: loss 1.725727
# iteration 300 / 2000: loss 1.762009
# iteration 400 / 2000: loss 1.611520
# iteration 500 / 2000: loss 1.722972
# iteration 600 / 2000: loss 1.704633
# iteration 700 / 2000: loss 1.447361
# iteration 800 / 2000: loss 1.506869
# iteration 900 / 2000: loss 1.394946
# iteration 1000 / 2000: loss 1.519365
# iteration 1100 / 2000: loss 1.506482
# iteration 1200 / 2000: loss 1.594212
# iteration 1300 / 2000: loss 1.379896
# iteration 1400 / 2000: loss 1.388274
# iteration 1500 / 2000: loss 1.524646
# iteration 1600 / 2000: loss 1.333029
# iteration 1700 / 2000: loss 1.526876
# iteration 1800 / 2000: loss 1.453083
# iteration 1900 / 2000: loss 1.361101
# hidden_size=80, lr=0.001000, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.496000
# iteration 0 / 2000: loss 2.303556
# iteration 100 / 2000: loss 1.968989
# iteration 200 / 2000: loss 1.800364
# iteration 300 / 2000: loss 1.759115
# iteration 400 / 2000: loss 1.800678
# iteration 500 / 2000: loss 1.485374
# iteration 600 / 2000: loss 1.542891
# iteration 700 / 2000: loss 1.416091
# iteration 800 / 2000: loss 1.557639
# iteration 900 / 2000: loss 1.568038
# iteration 1000 / 2000: loss 1.601662
# iteration 1100 / 2000: loss 1.498733
# iteration 1200 / 2000: loss 1.428365
# iteration 1300 / 2000: loss 1.527474
# iteration 1400 / 2000: loss 1.541346
# iteration 1500 / 2000: loss 1.485429
# iteration 1600 / 2000: loss 1.590436
# iteration 1700 / 2000: loss 1.407678
# iteration 1800 / 2000: loss 1.461101
# iteration 1900 / 2000: loss 1.489369
# hidden_size=80, lr=0.001000, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.501000
# iteration 0 / 2000: loss 2.302974
# iteration 100 / 2000: loss 2.302337
# iteration 200 / 2000: loss 2.295132
# iteration 300 / 2000: loss 2.233038
# iteration 400 / 2000: loss 2.208770
# iteration 500 / 2000: loss 2.113830
# iteration 600 / 2000: loss 2.062795
# iteration 700 / 2000: loss 2.032237
# iteration 800 / 2000: loss 1.968242
# iteration 900 / 2000: loss 1.962053
# iteration 1000 / 2000: loss 1.984881
# iteration 1100 / 2000: loss 1.932173
# iteration 1200 / 2000: loss 1.844393
# iteration 1300 / 2000: loss 1.854960
# iteration 1400 / 2000: loss 1.832038
# iteration 1500 / 2000: loss 1.810513
# iteration 1600 / 2000: loss 1.892508
# iteration 1700 / 2000: loss 1.851215
# iteration 1800 / 2000: loss 1.793126
# iteration 1900 / 2000: loss 1.666114
# hidden_size=80, lr=0.000100, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.367000
# iteration 0 / 2000: loss 2.303209
# iteration 100 / 2000: loss 2.302658
# iteration 200 / 2000: loss 2.296036
# iteration 300 / 2000: loss 2.257102
# iteration 400 / 2000: loss 2.165625
# iteration 500 / 2000: loss 2.094853
# iteration 600 / 2000: loss 2.014036
# iteration 700 / 2000: loss 2.037095
# iteration 800 / 2000: loss 1.941465
# iteration 900 / 2000: loss 1.928366
# iteration 1000 / 2000: loss 1.958010
# iteration 1100 / 2000: loss 1.830285
# iteration 1200 / 2000: loss 1.913896
# iteration 1300 / 2000: loss 1.928764
# iteration 1400 / 2000: loss 1.985478
# iteration 1500 / 2000: loss 1.757610
# iteration 1600 / 2000: loss 1.734445
# iteration 1700 / 2000: loss 1.793991
# iteration 1800 / 2000: loss 1.932467
# iteration 1900 / 2000: loss 1.873486
# hidden_size=80, lr=0.000100, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.365000
# iteration 0 / 2000: loss 2.303558
# iteration 100 / 2000: loss 2.303117
# iteration 200 / 2000: loss 2.297982
# iteration 300 / 2000: loss 2.251154
# iteration 400 / 2000: loss 2.149607
# iteration 500 / 2000: loss 2.119837
# iteration 600 / 2000: loss 2.087123
# iteration 700 / 2000: loss 2.005525
# iteration 800 / 2000: loss 1.934444
# iteration 900 / 2000: loss 1.915414
# iteration 1000 / 2000: loss 1.882094
# iteration 1100 / 2000: loss 1.943243
# iteration 1200 / 2000: loss 1.914119
# iteration 1300 / 2000: loss 1.900004
# iteration 1400 / 2000: loss 1.927891
# iteration 1500 / 2000: loss 1.777483
# iteration 1600 / 2000: loss 1.831858
# iteration 1700 / 2000: loss 1.807384
# iteration 1800 / 2000: loss 1.751146
# iteration 1900 / 2000: loss 1.773473
# hidden_size=80, lr=0.000100, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.360000
# iteration 0 / 2000: loss 2.302957
# iteration 100 / 2000: loss 2.302162
# iteration 200 / 2000: loss 2.295588
# iteration 300 / 2000: loss 2.272200
# iteration 400 / 2000: loss 2.209981
# iteration 500 / 2000: loss 2.111096
# iteration 600 / 2000: loss 2.099132
# iteration 700 / 2000: loss 2.115261
# iteration 800 / 2000: loss 2.021240
# iteration 900 / 2000: loss 2.020399
# iteration 1000 / 2000: loss 1.945994
# iteration 1100 / 2000: loss 1.956952
# iteration 1200 / 2000: loss 1.924996
# iteration 1300 / 2000: loss 1.898243
# iteration 1400 / 2000: loss 1.898725
# iteration 1500 / 2000: loss 1.818030
# iteration 1600 / 2000: loss 1.878283
# iteration 1700 / 2000: loss 1.876376
# iteration 1800 / 2000: loss 1.863186
# iteration 1900 / 2000: loss 2.046922
# hidden_size=80, lr=0.000100, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.337000
# iteration 0 / 2000: loss 2.303206
# iteration 100 / 2000: loss 2.302711
# iteration 200 / 2000: loss 2.298756
# iteration 300 / 2000: loss 2.262747
# iteration 400 / 2000: loss 2.231757
# iteration 500 / 2000: loss 2.113378
# iteration 600 / 2000: loss 2.060115
# iteration 700 / 2000: loss 2.056722
# iteration 800 / 2000: loss 2.038251
# iteration 900 / 2000: loss 2.029133
# iteration 1000 / 2000: loss 2.015929
# iteration 1100 / 2000: loss 1.910789
# iteration 1200 / 2000: loss 1.997242
# iteration 1300 / 2000: loss 1.983851
# iteration 1400 / 2000: loss 1.922566
# iteration 1500 / 2000: loss 1.949476
# iteration 1600 / 2000: loss 1.745646
# iteration 1700 / 2000: loss 1.855886
# iteration 1800 / 2000: loss 1.931315
# iteration 1900 / 2000: loss 1.897032
# hidden_size=80, lr=0.000100, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.335000
# iteration 0 / 2000: loss 2.303533
# iteration 100 / 2000: loss 2.302824
# iteration 200 / 2000: loss 2.297229
# iteration 300 / 2000: loss 2.241757
# iteration 400 / 2000: loss 2.177793
# iteration 500 / 2000: loss 2.182600
# iteration 600 / 2000: loss 2.080431
# iteration 700 / 2000: loss 2.107789
# iteration 800 / 2000: loss 2.026942
# iteration 900 / 2000: loss 2.018871
# iteration 1000 / 2000: loss 2.009166
# iteration 1100 / 2000: loss 1.930162
# iteration 1200 / 2000: loss 2.011505
# iteration 1300 / 2000: loss 1.949718
# iteration 1400 / 2000: loss 1.945104
# iteration 1500 / 2000: loss 1.809200
# iteration 1600 / 2000: loss 1.846604
# iteration 1700 / 2000: loss 1.880152
# iteration 1800 / 2000: loss 1.858300
# iteration 1900 / 2000: loss 1.842251
# hidden_size=80, lr=0.000100, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.328000
# iteration 0 / 2000: loss 2.302932
# iteration 100 / 2000: loss 2.302918
# iteration 200 / 2000: loss 2.302875
# iteration 300 / 2000: loss 2.302809
# iteration 400 / 2000: loss 2.302745
# iteration 500 / 2000: loss 2.302739
# iteration 600 / 2000: loss 2.302652
# iteration 700 / 2000: loss 2.302437
# iteration 800 / 2000: loss 2.302388
# iteration 900 / 2000: loss 2.302292
# iteration 1000 / 2000: loss 2.302291
# iteration 1100 / 2000: loss 2.301971
# iteration 1200 / 2000: loss 2.301969
# iteration 1300 / 2000: loss 2.301294
# iteration 1400 / 2000: loss 2.301400
# iteration 1500 / 2000: loss 2.300805
# iteration 1600 / 2000: loss 2.301219
# iteration 1700 / 2000: loss 2.299437
# iteration 1800 / 2000: loss 2.300621
# iteration 1900 / 2000: loss 2.298393
# hidden_size=80, lr=0.000010, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.180000
# iteration 0 / 2000: loss 2.303178
# iteration 100 / 2000: loss 2.303167
# iteration 200 / 2000: loss 2.303115
# iteration 300 / 2000: loss 2.303059
# iteration 400 / 2000: loss 2.303082
# iteration 500 / 2000: loss 2.302883
# iteration 600 / 2000: loss 2.302902
# iteration 700 / 2000: loss 2.302801
# iteration 800 / 2000: loss 2.302763
# iteration 900 / 2000: loss 2.302553
# iteration 1000 / 2000: loss 2.302597
# iteration 1100 / 2000: loss 2.302442
# iteration 1200 / 2000: loss 2.302415
# iteration 1300 / 2000: loss 2.301873
# iteration 1400 / 2000: loss 2.301582
# iteration 1500 / 2000: loss 2.301559
# iteration 1600 / 2000: loss 2.301986
# iteration 1700 / 2000: loss 2.300592
# iteration 1800 / 2000: loss 2.300293
# iteration 1900 / 2000: loss 2.300643
# hidden_size=80, lr=0.000010, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.180000
# iteration 0 / 2000: loss 2.303565
# iteration 100 / 2000: loss 2.303516
# iteration 200 / 2000: loss 2.303497
# iteration 300 / 2000: loss 2.303455
# iteration 400 / 2000: loss 2.303470
# iteration 500 / 2000: loss 2.303392
# iteration 600 / 2000: loss 2.303236
# iteration 700 / 2000: loss 2.303245
# iteration 800 / 2000: loss 2.303169
# iteration 900 / 2000: loss 2.303050
# iteration 1000 / 2000: loss 2.302923
# iteration 1100 / 2000: loss 2.302742
# iteration 1200 / 2000: loss 2.302537
# iteration 1300 / 2000: loss 2.302614
# iteration 1400 / 2000: loss 2.302035
# iteration 1500 / 2000: loss 2.301687
# iteration 1600 / 2000: loss 2.301673
# iteration 1700 / 2000: loss 2.301055
# iteration 1800 / 2000: loss 2.300750
# iteration 1900 / 2000: loss 2.300641
# hidden_size=80, lr=0.000010, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.197000
# iteration 0 / 2000: loss 2.302985
# iteration 100 / 2000: loss 2.302918
# iteration 200 / 2000: loss 2.302910
# iteration 300 / 2000: loss 2.302854
# iteration 400 / 2000: loss 2.302846
# iteration 500 / 2000: loss 2.302784
# iteration 600 / 2000: loss 2.302828
# iteration 700 / 2000: loss 2.302764
# iteration 800 / 2000: loss 2.302633
# iteration 900 / 2000: loss 2.302600
# iteration 1000 / 2000: loss 2.302579
# iteration 1100 / 2000: loss 2.302562
# iteration 1200 / 2000: loss 2.302531
# iteration 1300 / 2000: loss 2.302471
# iteration 1400 / 2000: loss 2.302384
# iteration 1500 / 2000: loss 2.302378
# iteration 1600 / 2000: loss 2.302160
# iteration 1700 / 2000: loss 2.302218
# iteration 1800 / 2000: loss 2.301717
# iteration 1900 / 2000: loss 2.301710
# hidden_size=80, lr=0.000010, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.200000
# iteration 0 / 2000: loss 2.303234
# iteration 100 / 2000: loss 2.303159
# iteration 200 / 2000: loss 2.303159
# iteration 300 / 2000: loss 2.303114
# iteration 400 / 2000: loss 2.303027
# iteration 500 / 2000: loss 2.303006
# iteration 600 / 2000: loss 2.302987
# iteration 700 / 2000: loss 2.302880
# iteration 800 / 2000: loss 2.302874
# iteration 900 / 2000: loss 2.302790
# iteration 1000 / 2000: loss 2.302736
# iteration 1100 / 2000: loss 2.302615
# iteration 1200 / 2000: loss 2.302551
# iteration 1300 / 2000: loss 2.302588
# iteration 1400 / 2000: loss 2.302422
# iteration 1500 / 2000: loss 2.302144
# iteration 1600 / 2000: loss 2.302088
# iteration 1700 / 2000: loss 2.302126
# iteration 1800 / 2000: loss 2.302024
# iteration 1900 / 2000: loss 2.301522
# hidden_size=80, lr=0.000010, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.213000
# iteration 0 / 2000: loss 2.303571
# iteration 100 / 2000: loss 2.303523
# iteration 200 / 2000: loss 2.303499
# iteration 300 / 2000: loss 2.303451
# iteration 400 / 2000: loss 2.303434
# iteration 500 / 2000: loss 2.303374
# iteration 600 / 2000: loss 2.303343
# iteration 700 / 2000: loss 2.303295
# iteration 800 / 2000: loss 2.303194
# iteration 900 / 2000: loss 2.303113
# iteration 1000 / 2000: loss 2.303082
# iteration 1100 / 2000: loss 2.302976
# iteration 1200 / 2000: loss 2.302928
# iteration 1300 / 2000: loss 2.302654
# iteration 1400 / 2000: loss 2.302756
# iteration 1500 / 2000: loss 2.302612
# iteration 1600 / 2000: loss 2.302760
# iteration 1700 / 2000: loss 2.302330
# iteration 1800 / 2000: loss 2.302452
# iteration 1900 / 2000: loss 2.301966
# hidden_size=80, lr=0.000010, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.234000
# iteration 0 / 2000: loss 2.303059
# iteration 100 / 2000: loss 1.961889
# iteration 200 / 2000: loss 1.736496
# iteration 300 / 2000: loss 1.633250
# iteration 400 / 2000: loss 1.627437
# iteration 500 / 2000: loss 1.572954
# iteration 600 / 2000: loss 1.474898
# iteration 700 / 2000: loss 1.481855
# iteration 800 / 2000: loss 1.429138
# iteration 900 / 2000: loss 1.532672
# iteration 1000 / 2000: loss 1.460507
# iteration 1100 / 2000: loss 1.404549
# iteration 1200 / 2000: loss 1.445235
# iteration 1300 / 2000: loss 1.552072
# iteration 1400 / 2000: loss 1.535298
# iteration 1500 / 2000: loss 1.432482
# iteration 1600 / 2000: loss 1.378282
# iteration 1700 / 2000: loss 1.299340
# iteration 1800 / 2000: loss 1.347034
# iteration 1900 / 2000: loss 1.391231
# hidden_size=100, lr=0.001000, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.504000
# iteration 0 / 2000: loss 2.303388
# iteration 100 / 2000: loss 1.989909
# iteration 200 / 2000: loss 1.742257
# iteration 300 / 2000: loss 1.679232
# iteration 400 / 2000: loss 1.656210
# iteration 500 / 2000: loss 1.494081
# iteration 600 / 2000: loss 1.451302
# iteration 700 / 2000: loss 1.709313
# iteration 800 / 2000: loss 1.514931
# iteration 900 / 2000: loss 1.415483
# iteration 1000 / 2000: loss 1.493604
# iteration 1100 / 2000: loss 1.528474
# iteration 1200 / 2000: loss 1.482423
# iteration 1300 / 2000: loss 1.472838
# iteration 1400 / 2000: loss 1.375001
# iteration 1500 / 2000: loss 1.458805
# iteration 1600 / 2000: loss 1.446906
# iteration 1700 / 2000: loss 1.505600
# iteration 1800 / 2000: loss 1.449664
# iteration 1900 / 2000: loss 1.338936
# hidden_size=100, lr=0.001000, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.502000
# iteration 0 / 2000: loss 2.303821
# iteration 100 / 2000: loss 1.923429
# iteration 200 / 2000: loss 1.844024
# iteration 300 / 2000: loss 1.672093
# iteration 400 / 2000: loss 1.660379
# iteration 500 / 2000: loss 1.686142
# iteration 600 / 2000: loss 1.458330
# iteration 700 / 2000: loss 1.644570
# iteration 800 / 2000: loss 1.668226
# iteration 900 / 2000: loss 1.433015
# iteration 1000 / 2000: loss 1.606953
# iteration 1100 / 2000: loss 1.567017
# iteration 1200 / 2000: loss 1.568188
# iteration 1300 / 2000: loss 1.541966
# iteration 1400 / 2000: loss 1.509751
# iteration 1500 / 2000: loss 1.506562
# iteration 1600 / 2000: loss 1.543089
# iteration 1700 / 2000: loss 1.561208
# iteration 1800 / 2000: loss 1.556681
# iteration 1900 / 2000: loss 1.352437
# hidden_size=100, lr=0.001000, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.497000
# iteration 0 / 2000: loss 2.303055
# iteration 100 / 2000: loss 1.972780
# iteration 200 / 2000: loss 1.826140
# iteration 300 / 2000: loss 1.714003
# iteration 400 / 2000: loss 1.668396
# iteration 500 / 2000: loss 1.589152
# iteration 600 / 2000: loss 1.487275
# iteration 700 / 2000: loss 1.520035
# iteration 800 / 2000: loss 1.532048
# iteration 900 / 2000: loss 1.571320
# iteration 1000 / 2000: loss 1.448341
# iteration 1100 / 2000: loss 1.496590
# iteration 1200 / 2000: loss 1.435708
# iteration 1300 / 2000: loss 1.460179
# iteration 1400 / 2000: loss 1.551554
# iteration 1500 / 2000: loss 1.504691
# iteration 1600 / 2000: loss 1.413791
# iteration 1700 / 2000: loss 1.335973
# iteration 1800 / 2000: loss 1.306199
# iteration 1900 / 2000: loss 1.302904
# hidden_size=100, lr=0.001000, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.509000
# iteration 0 / 2000: loss 2.303323
# iteration 100 / 2000: loss 1.866241
# iteration 200 / 2000: loss 1.798603
# iteration 300 / 2000: loss 1.631578
# iteration 400 / 2000: loss 1.575731
# iteration 500 / 2000: loss 1.557524
# iteration 600 / 2000: loss 1.523436
# iteration 700 / 2000: loss 1.488256
# iteration 800 / 2000: loss 1.531817
# iteration 900 / 2000: loss 1.387504
# iteration 1000 / 2000: loss 1.468060
# iteration 1100 / 2000: loss 1.462717
# iteration 1200 / 2000: loss 1.501613
# iteration 1300 / 2000: loss 1.609752
# iteration 1400 / 2000: loss 1.376121
# iteration 1500 / 2000: loss 1.389831
# iteration 1600 / 2000: loss 1.431466
# iteration 1700 / 2000: loss 1.423361
# iteration 1800 / 2000: loss 1.415838
# iteration 1900 / 2000: loss 1.434687
# hidden_size=100, lr=0.001000, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.514000
# iteration 0 / 2000: loss 2.303796
# iteration 100 / 2000: loss 1.946785
# iteration 200 / 2000: loss 1.811212
# iteration 300 / 2000: loss 1.666570
# iteration 400 / 2000: loss 1.576186
# iteration 500 / 2000: loss 1.530143
# iteration 600 / 2000: loss 1.549602
# iteration 700 / 2000: loss 1.595574
# iteration 800 / 2000: loss 1.550565
# iteration 900 / 2000: loss 1.572073
# iteration 1000 / 2000: loss 1.624800
# iteration 1100 / 2000: loss 1.562949
# iteration 1200 / 2000: loss 1.605029
# iteration 1300 / 2000: loss 1.566894
# iteration 1400 / 2000: loss 1.403548
# iteration 1500 / 2000: loss 1.498749
# iteration 1600 / 2000: loss 1.466582
# iteration 1700 / 2000: loss 1.503619
# iteration 1800 / 2000: loss 1.374538
# iteration 1900 / 2000: loss 1.497783
# hidden_size=100, lr=0.001000, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.503000
# iteration 0 / 2000: loss 2.303066
# iteration 100 / 2000: loss 2.302144
# iteration 200 / 2000: loss 2.291494
# iteration 300 / 2000: loss 2.220648
# iteration 400 / 2000: loss 2.109680
# iteration 500 / 2000: loss 2.127256
# iteration 600 / 2000: loss 2.039225
# iteration 700 / 2000: loss 2.053853
# iteration 800 / 2000: loss 1.972550
# iteration 900 / 2000: loss 1.940054
# iteration 1000 / 2000: loss 1.881246
# iteration 1100 / 2000: loss 1.964943
# iteration 1200 / 2000: loss 1.866054
# iteration 1300 / 2000: loss 1.974050
# iteration 1400 / 2000: loss 1.874521
# iteration 1500 / 2000: loss 1.782617
# iteration 1600 / 2000: loss 1.811455
# iteration 1700 / 2000: loss 1.858833
# iteration 1800 / 2000: loss 1.830149
# iteration 1900 / 2000: loss 1.840852
# hidden_size=100, lr=0.000100, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.368000
# iteration 0 / 2000: loss 2.303358
# iteration 100 / 2000: loss 2.302696
# iteration 200 / 2000: loss 2.297538
# iteration 300 / 2000: loss 2.252958
# iteration 400 / 2000: loss 2.192589
# iteration 500 / 2000: loss 2.111097
# iteration 600 / 2000: loss 2.063587
# iteration 700 / 2000: loss 2.054940
# iteration 800 / 2000: loss 2.018479
# iteration 900 / 2000: loss 1.995540
# iteration 1000 / 2000: loss 1.923432
# iteration 1100 / 2000: loss 2.010175
# iteration 1200 / 2000: loss 1.955378
# iteration 1300 / 2000: loss 2.018011
# iteration 1400 / 2000: loss 1.987634
# iteration 1500 / 2000: loss 1.866817
# iteration 1600 / 2000: loss 1.783000
# iteration 1700 / 2000: loss 1.826217
# iteration 1800 / 2000: loss 1.774204
# iteration 1900 / 2000: loss 1.883078
# hidden_size=100, lr=0.000100, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.362000
# iteration 0 / 2000: loss 2.303857
# iteration 100 / 2000: loss 2.303038
# iteration 200 / 2000: loss 2.296280
# iteration 300 / 2000: loss 2.252925
# iteration 400 / 2000: loss 2.145971
# iteration 500 / 2000: loss 2.106502
# iteration 600 / 2000: loss 2.070638
# iteration 700 / 2000: loss 2.061118
# iteration 800 / 2000: loss 1.969203
# iteration 900 / 2000: loss 1.922239
# iteration 1000 / 2000: loss 2.036032
# iteration 1100 / 2000: loss 1.953933
# iteration 1200 / 2000: loss 1.951168
# iteration 1300 / 2000: loss 1.891148
# iteration 1400 / 2000: loss 1.882327
# iteration 1500 / 2000: loss 1.754867
# iteration 1600 / 2000: loss 1.948216
# iteration 1700 / 2000: loss 1.729836
# iteration 1800 / 2000: loss 1.831063
# iteration 1900 / 2000: loss 1.819485
# hidden_size=100, lr=0.000100, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.362000
# iteration 0 / 2000: loss 2.303077
# iteration 100 / 2000: loss 2.302202
# iteration 200 / 2000: loss 2.296203
# iteration 300 / 2000: loss 2.257933
# iteration 400 / 2000: loss 2.197100
# iteration 500 / 2000: loss 2.172846
# iteration 600 / 2000: loss 2.029166
# iteration 700 / 2000: loss 2.015817
# iteration 800 / 2000: loss 2.073278
# iteration 900 / 2000: loss 1.986049
# iteration 1000 / 2000: loss 1.920172
# iteration 1100 / 2000: loss 1.912171
# iteration 1200 / 2000: loss 1.938543
# iteration 1300 / 2000: loss 2.026606
# iteration 1400 / 2000: loss 1.814080
# iteration 1500 / 2000: loss 1.845392
# iteration 1600 / 2000: loss 1.966781
# iteration 1700 / 2000: loss 1.790486
# iteration 1800 / 2000: loss 1.799126
# iteration 1900 / 2000: loss 1.971364
# hidden_size=100, lr=0.000100, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.340000
# iteration 0 / 2000: loss 2.303336
# iteration 100 / 2000: loss 2.302536
# iteration 200 / 2000: loss 2.297874
# iteration 300 / 2000: loss 2.260071
# iteration 400 / 2000: loss 2.205551
# iteration 500 / 2000: loss 2.111111
# iteration 600 / 2000: loss 2.063488
# iteration 700 / 2000: loss 1.992790
# iteration 800 / 2000: loss 2.016724
# iteration 900 / 2000: loss 1.956150
# iteration 1000 / 2000: loss 1.942835
# iteration 1100 / 2000: loss 2.002197
# iteration 1200 / 2000: loss 1.944484
# iteration 1300 / 2000: loss 1.937866
# iteration 1400 / 2000: loss 1.861558
# iteration 1500 / 2000: loss 1.889179
# iteration 1600 / 2000: loss 1.896382
# iteration 1700 / 2000: loss 1.844421
# iteration 1800 / 2000: loss 1.871714
# iteration 1900 / 2000: loss 1.813542
# hidden_size=100, lr=0.000100, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.337000
# iteration 0 / 2000: loss 2.303812
# iteration 100 / 2000: loss 2.303123
# iteration 200 / 2000: loss 2.296950
# iteration 300 / 2000: loss 2.269403
# iteration 400 / 2000: loss 2.181701
# iteration 500 / 2000: loss 2.113752
# iteration 600 / 2000: loss 2.083568
# iteration 700 / 2000: loss 2.010826
# iteration 800 / 2000: loss 2.080185
# iteration 900 / 2000: loss 2.034172
# iteration 1000 / 2000: loss 2.023221
# iteration 1100 / 2000: loss 1.951836
# iteration 1200 / 2000: loss 1.933593
# iteration 1300 / 2000: loss 1.958279
# iteration 1400 / 2000: loss 1.921301
# iteration 1500 / 2000: loss 1.851072
# iteration 1600 / 2000: loss 1.847567
# iteration 1700 / 2000: loss 1.879930
# iteration 1800 / 2000: loss 1.861231
# iteration 1900 / 2000: loss 1.836235
# hidden_size=100, lr=0.000100, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.335000
# iteration 0 / 2000: loss 2.303054
# iteration 100 / 2000: loss 2.303023
# iteration 200 / 2000: loss 2.302982
# iteration 300 / 2000: loss 2.302937
# iteration 400 / 2000: loss 2.302928
# iteration 500 / 2000: loss 2.302841
# iteration 600 / 2000: loss 2.302749
# iteration 700 / 2000: loss 2.302741
# iteration 800 / 2000: loss 2.302652
# iteration 900 / 2000: loss 2.302389
# iteration 1000 / 2000: loss 2.302419
# iteration 1100 / 2000: loss 2.302123
# iteration 1200 / 2000: loss 2.301813
# iteration 1300 / 2000: loss 2.302098
# iteration 1400 / 2000: loss 2.301697
# iteration 1500 / 2000: loss 2.301454
# iteration 1600 / 2000: loss 2.301527
# iteration 1700 / 2000: loss 2.300077
# iteration 1800 / 2000: loss 2.300231
# iteration 1900 / 2000: loss 2.299533
# hidden_size=100, lr=0.000010, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.174000
# iteration 0 / 2000: loss 2.303349
# iteration 100 / 2000: loss 2.303285
# iteration 200 / 2000: loss 2.303262
# iteration 300 / 2000: loss 2.303176
# iteration 400 / 2000: loss 2.303152
# iteration 500 / 2000: loss 2.303075
# iteration 600 / 2000: loss 2.303006
# iteration 700 / 2000: loss 2.303074
# iteration 800 / 2000: loss 2.302911
# iteration 900 / 2000: loss 2.302738
# iteration 1000 / 2000: loss 2.302540
# iteration 1100 / 2000: loss 2.302377
# iteration 1200 / 2000: loss 2.302093
# iteration 1300 / 2000: loss 2.301939
# iteration 1400 / 2000: loss 2.301935
# iteration 1500 / 2000: loss 2.301320
# iteration 1600 / 2000: loss 2.300571
# iteration 1700 / 2000: loss 2.300231
# iteration 1800 / 2000: loss 2.299011
# iteration 1900 / 2000: loss 2.298584
# hidden_size=100, lr=0.000010, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.205000
# iteration 0 / 2000: loss 2.303852
# iteration 100 / 2000: loss 2.303783
# iteration 200 / 2000: loss 2.303753
# iteration 300 / 2000: loss 2.303661
# iteration 400 / 2000: loss 2.303618
# iteration 500 / 2000: loss 2.303530
# iteration 600 / 2000: loss 2.303388
# iteration 700 / 2000: loss 2.303428
# iteration 800 / 2000: loss 2.303298
# iteration 900 / 2000: loss 2.303129
# iteration 1000 / 2000: loss 2.302731
# iteration 1100 / 2000: loss 2.302728
# iteration 1200 / 2000: loss 2.302584
# iteration 1300 / 2000: loss 2.302248
# iteration 1400 / 2000: loss 2.302513
# iteration 1500 / 2000: loss 2.302094
# iteration 1600 / 2000: loss 2.301650
# iteration 1700 / 2000: loss 2.301252
# iteration 1800 / 2000: loss 2.301104
# iteration 1900 / 2000: loss 2.299193
# hidden_size=100, lr=0.000010, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.185000
# iteration 0 / 2000: loss 2.302983
# iteration 100 / 2000: loss 2.302961
# iteration 200 / 2000: loss 2.302968
# iteration 300 / 2000: loss 2.302906
# iteration 400 / 2000: loss 2.302851
# iteration 500 / 2000: loss 2.302760
# iteration 600 / 2000: loss 2.302646
# iteration 700 / 2000: loss 2.302662
# iteration 800 / 2000: loss 2.302530
# iteration 900 / 2000: loss 2.302516
# iteration 1000 / 2000: loss 2.302459
# iteration 1100 / 2000: loss 2.302229
# iteration 1200 / 2000: loss 2.301872
# iteration 1300 / 2000: loss 2.301802
# iteration 1400 / 2000: loss 2.301915
# iteration 1500 / 2000: loss 2.301780
# iteration 1600 / 2000: loss 2.301583
# iteration 1700 / 2000: loss 2.301466
# iteration 1800 / 2000: loss 2.301257
# iteration 1900 / 2000: loss 2.301221
# hidden_size=100, lr=0.000010, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.210000
# iteration 0 / 2000: loss 2.303358
# iteration 100 / 2000: loss 2.303336
# iteration 200 / 2000: loss 2.303259
# iteration 300 / 2000: loss 2.303211
# iteration 400 / 2000: loss 2.303183
# iteration 500 / 2000: loss 2.303083
# iteration 600 / 2000: loss 2.303068
# iteration 700 / 2000: loss 2.303017
# iteration 800 / 2000: loss 2.302869
# iteration 900 / 2000: loss 2.302793
# iteration 1000 / 2000: loss 2.302722
# iteration 1100 / 2000: loss 2.302695
# iteration 1200 / 2000: loss 2.302456
# iteration 1300 / 2000: loss 2.302548
# iteration 1400 / 2000: loss 2.302242
# iteration 1500 / 2000: loss 2.302335
# iteration 1600 / 2000: loss 2.301727
# iteration 1700 / 2000: loss 2.302032
# iteration 1800 / 2000: loss 2.301778
# iteration 1900 / 2000: loss 2.301742
# hidden_size=100, lr=0.000010, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.216000
# iteration 0 / 2000: loss 2.303811
# iteration 100 / 2000: loss 2.303788
# iteration 200 / 2000: loss 2.303698
# iteration 300 / 2000: loss 2.303691
# iteration 400 / 2000: loss 2.303652
# iteration 500 / 2000: loss 2.303577
# iteration 600 / 2000: loss 2.303574
# iteration 700 / 2000: loss 2.303528
# iteration 800 / 2000: loss 2.303394
# iteration 900 / 2000: loss 2.303429
# iteration 1000 / 2000: loss 2.303340
# iteration 1100 / 2000: loss 2.303291
# iteration 1200 / 2000: loss 2.303035
# iteration 1300 / 2000: loss 2.302838
# iteration 1400 / 2000: loss 2.302724
# iteration 1500 / 2000: loss 2.302811
# iteration 1600 / 2000: loss 2.302434
# iteration 1700 / 2000: loss 2.302494
# iteration 1800 / 2000: loss 2.302466
# iteration 1900 / 2000: loss 2.302598
# hidden_size=100, lr=0.000010, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.221000
# iteration 0 / 2000: loss 2.303323
# iteration 100 / 2000: loss 1.844984
# iteration 200 / 2000: loss 1.798167
# iteration 300 / 2000: loss 1.603313
# iteration 400 / 2000: loss 1.666694
# iteration 500 / 2000: loss 1.531086
# iteration 600 / 2000: loss 1.628220
# iteration 700 / 2000: loss 1.297245
# iteration 800 / 2000: loss 1.532368
# iteration 900 / 2000: loss 1.428436
# iteration 1000 / 2000: loss 1.484543
# iteration 1100 / 2000: loss 1.379828
# iteration 1200 / 2000: loss 1.411000
# iteration 1300 / 2000: loss 1.522797
# iteration 1400 / 2000: loss 1.375171
# iteration 1500 / 2000: loss 1.386085
# iteration 1600 / 2000: loss 1.458143
# iteration 1700 / 2000: loss 1.348544
# iteration 1800 / 2000: loss 1.630634
# iteration 1900 / 2000: loss 1.364041
# hidden_size=150, lr=0.001000, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.514000
# iteration 0 / 2000: loss 2.303681
# iteration 100 / 2000: loss 1.844943
# iteration 200 / 2000: loss 1.818262
# iteration 300 / 2000: loss 1.701938
# iteration 400 / 2000: loss 1.608532
# iteration 500 / 2000: loss 1.628885
# iteration 600 / 2000: loss 1.652473
# iteration 700 / 2000: loss 1.608984
# iteration 800 / 2000: loss 1.533349
# iteration 900 / 2000: loss 1.454636
# iteration 1000 / 2000: loss 1.344552
# iteration 1100 / 2000: loss 1.454721
# iteration 1200 / 2000: loss 1.396279
# iteration 1300 / 2000: loss 1.574262
# iteration 1400 / 2000: loss 1.360563
# iteration 1500 / 2000: loss 1.299516
# iteration 1600 / 2000: loss 1.580256
# iteration 1700 / 2000: loss 1.599867
# iteration 1800 / 2000: loss 1.146567
# iteration 1900 / 2000: loss 1.400920
# hidden_size=150, lr=0.001000, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.506000
# iteration 0 / 2000: loss 2.304403
# iteration 100 / 2000: loss 1.950525
# iteration 200 / 2000: loss 1.717773
# iteration 300 / 2000: loss 1.774296
# iteration 400 / 2000: loss 1.651828
# iteration 500 / 2000: loss 1.615144
# iteration 600 / 2000: loss 1.568871
# iteration 700 / 2000: loss 1.487844
# iteration 800 / 2000: loss 1.445858
# iteration 900 / 2000: loss 1.481046
# iteration 1000 / 2000: loss 1.433308
# iteration 1100 / 2000: loss 1.473324
# iteration 1200 / 2000: loss 1.508076
# iteration 1300 / 2000: loss 1.460905
# iteration 1400 / 2000: loss 1.549145
# iteration 1500 / 2000: loss 1.494767
# iteration 1600 / 2000: loss 1.416331
# iteration 1700 / 2000: loss 1.410878
# iteration 1800 / 2000: loss 1.478031
# iteration 1900 / 2000: loss 1.446697
# hidden_size=150, lr=0.001000, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.490000
# iteration 0 / 2000: loss 2.303321
# iteration 100 / 2000: loss 1.906061
# iteration 200 / 2000: loss 1.859459
# iteration 300 / 2000: loss 1.741271
# iteration 400 / 2000: loss 1.788628
# iteration 500 / 2000: loss 1.576479
# iteration 600 / 2000: loss 1.592339
# iteration 700 / 2000: loss 1.551115
# iteration 800 / 2000: loss 1.438247
# iteration 900 / 2000: loss 1.501525
# iteration 1000 / 2000: loss 1.496011
# iteration 1100 / 2000: loss 1.307325
# iteration 1200 / 2000: loss 1.433764
# iteration 1300 / 2000: loss 1.492228
# iteration 1400 / 2000: loss 1.362394
# iteration 1500 / 2000: loss 1.528981
# iteration 1600 / 2000: loss 1.386273
# iteration 1700 / 2000: loss 1.550462
# iteration 1800 / 2000: loss 1.412865
# iteration 1900 / 2000: loss 1.365600
# hidden_size=150, lr=0.001000, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.506000
# iteration 0 / 2000: loss 2.303762
# iteration 100 / 2000: loss 1.980572
# iteration 200 / 2000: loss 1.710207
# iteration 300 / 2000: loss 1.592684
# iteration 400 / 2000: loss 1.608724
# iteration 500 / 2000: loss 1.677611
# iteration 600 / 2000: loss 1.548573
# iteration 700 / 2000: loss 1.643003
# iteration 800 / 2000: loss 1.536418
# iteration 900 / 2000: loss 1.307993
# iteration 1000 / 2000: loss 1.561680
# iteration 1100 / 2000: loss 1.586133
# iteration 1200 / 2000: loss 1.480795
# iteration 1300 / 2000: loss 1.396723
# iteration 1400 / 2000: loss 1.474204
# iteration 1500 / 2000: loss 1.588794
# iteration 1600 / 2000: loss 1.278075
# iteration 1700 / 2000: loss 1.444836
# iteration 1800 / 2000: loss 1.334086
# iteration 1900 / 2000: loss 1.288578
# hidden_size=150, lr=0.001000, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.508000
# iteration 0 / 2000: loss 2.304428
# iteration 100 / 2000: loss 1.999439
# iteration 200 / 2000: loss 1.810460
# iteration 300 / 2000: loss 1.604649
# iteration 400 / 2000: loss 1.557422
# iteration 500 / 2000: loss 1.603438
# iteration 600 / 2000: loss 1.558781
# iteration 700 / 2000: loss 1.535762
# iteration 800 / 2000: loss 1.615322
# iteration 900 / 2000: loss 1.510577
# iteration 1000 / 2000: loss 1.491769
# iteration 1100 / 2000: loss 1.460928
# iteration 1200 / 2000: loss 1.632464
# iteration 1300 / 2000: loss 1.597778
# iteration 1400 / 2000: loss 1.584893
# iteration 1500 / 2000: loss 1.448616
# iteration 1600 / 2000: loss 1.417631
# iteration 1700 / 2000: loss 1.559671
# iteration 1800 / 2000: loss 1.538707
# iteration 1900 / 2000: loss 1.425090
# hidden_size=150, lr=0.001000, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.494000
# iteration 0 / 2000: loss 2.303309
# iteration 100 / 2000: loss 2.302177
# iteration 200 / 2000: loss 2.291504
# iteration 300 / 2000: loss 2.240836
# iteration 400 / 2000: loss 2.135598
# iteration 500 / 2000: loss 2.063529
# iteration 600 / 2000: loss 2.111287
# iteration 700 / 2000: loss 1.960444
# iteration 800 / 2000: loss 1.942618
# iteration 900 / 2000: loss 1.966015
# iteration 1000 / 2000: loss 1.859263
# iteration 1100 / 2000: loss 1.918514
# iteration 1200 / 2000: loss 1.862644
# iteration 1300 / 2000: loss 1.939306
# iteration 1400 / 2000: loss 1.876121
# iteration 1500 / 2000: loss 1.864239
# iteration 1600 / 2000: loss 1.837678
# iteration 1700 / 2000: loss 1.843514
# iteration 1800 / 2000: loss 1.676143
# iteration 1900 / 2000: loss 1.804060
# hidden_size=150, lr=0.000100, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.380000
# iteration 0 / 2000: loss 2.303714
# iteration 100 / 2000: loss 2.302436
# iteration 200 / 2000: loss 2.289875
# iteration 300 / 2000: loss 2.204449
# iteration 400 / 2000: loss 2.177576
# iteration 500 / 2000: loss 2.053573
# iteration 600 / 2000: loss 2.006588
# iteration 700 / 2000: loss 1.989674
# iteration 800 / 2000: loss 2.022586
# iteration 900 / 2000: loss 1.955939
# iteration 1000 / 2000: loss 1.890154
# iteration 1100 / 2000: loss 1.948444
# iteration 1200 / 2000: loss 1.826387
# iteration 1300 / 2000: loss 1.922545
# iteration 1400 / 2000: loss 1.928174
# iteration 1500 / 2000: loss 1.770058
# iteration 1600 / 2000: loss 1.864858
# iteration 1700 / 2000: loss 1.820743
# iteration 1800 / 2000: loss 1.771668
# iteration 1900 / 2000: loss 1.765366
# hidden_size=150, lr=0.000100, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.370000
# iteration 0 / 2000: loss 2.304502
# iteration 100 / 2000: loss 2.303223
# iteration 200 / 2000: loss 2.296966
# iteration 300 / 2000: loss 2.227507
# iteration 400 / 2000: loss 2.172976
# iteration 500 / 2000: loss 2.099404
# iteration 600 / 2000: loss 2.089562
# iteration 700 / 2000: loss 2.043396
# iteration 800 / 2000: loss 1.984845
# iteration 900 / 2000: loss 1.941867
# iteration 1000 / 2000: loss 1.951727
# iteration 1100 / 2000: loss 1.921761
# iteration 1200 / 2000: loss 1.934233
# iteration 1300 / 2000: loss 1.964463
# iteration 1400 / 2000: loss 1.792524
# iteration 1500 / 2000: loss 1.960568
# iteration 1600 / 2000: loss 1.860311
# iteration 1700 / 2000: loss 1.806293
# iteration 1800 / 2000: loss 1.802791
# iteration 1900 / 2000: loss 1.778342
# hidden_size=150, lr=0.000100, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.367000
# iteration 0 / 2000: loss 2.303287
# iteration 100 / 2000: loss 2.302096
# iteration 200 / 2000: loss 2.289905
# iteration 300 / 2000: loss 2.230938
# iteration 400 / 2000: loss 2.162240
# iteration 500 / 2000: loss 2.097583
# iteration 600 / 2000: loss 2.089292
# iteration 700 / 2000: loss 2.100946
# iteration 800 / 2000: loss 2.022498
# iteration 900 / 2000: loss 2.007905
# iteration 1000 / 2000: loss 1.985285
# iteration 1100 / 2000: loss 1.853571
# iteration 1200 / 2000: loss 1.961597
# iteration 1300 / 2000: loss 1.907942
# iteration 1400 / 2000: loss 1.853802
# iteration 1500 / 2000: loss 1.865921
# iteration 1600 / 2000: loss 1.868114
# iteration 1700 / 2000: loss 1.926302
# iteration 1800 / 2000: loss 1.870944
# iteration 1900 / 2000: loss 1.818351
# hidden_size=150, lr=0.000100, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.344000
# iteration 0 / 2000: loss 2.303780
# iteration 100 / 2000: loss 2.302713
# iteration 200 / 2000: loss 2.295010
# iteration 300 / 2000: loss 2.258216
# iteration 400 / 2000: loss 2.169924
# iteration 500 / 2000: loss 2.127498
# iteration 600 / 2000: loss 2.115104
# iteration 700 / 2000: loss 2.044008
# iteration 800 / 2000: loss 1.958653
# iteration 900 / 2000: loss 2.044293
# iteration 1000 / 2000: loss 2.062330
# iteration 1100 / 2000: loss 1.955359
# iteration 1200 / 2000: loss 1.979637
# iteration 1300 / 2000: loss 1.933017
# iteration 1400 / 2000: loss 1.814173
# iteration 1500 / 2000: loss 1.850534
# iteration 1600 / 2000: loss 1.885978
# iteration 1700 / 2000: loss 1.827173
# iteration 1800 / 2000: loss 1.830091
# iteration 1900 / 2000: loss 1.855199
# hidden_size=150, lr=0.000100, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.339000
# iteration 0 / 2000: loss 2.304455
# iteration 100 / 2000: loss 2.303480
# iteration 200 / 2000: loss 2.297041
# iteration 300 / 2000: loss 2.236130
# iteration 400 / 2000: loss 2.218858
# iteration 500 / 2000: loss 2.115346
# iteration 600 / 2000: loss 2.072980
# iteration 700 / 2000: loss 2.082024
# iteration 800 / 2000: loss 2.097490
# iteration 900 / 2000: loss 1.942743
# iteration 1000 / 2000: loss 1.998415
# iteration 1100 / 2000: loss 1.921014
# iteration 1200 / 2000: loss 1.905522
# iteration 1300 / 2000: loss 1.936253
# iteration 1400 / 2000: loss 1.932832
# iteration 1500 / 2000: loss 1.836776
# iteration 1600 / 2000: loss 1.738561
# iteration 1700 / 2000: loss 1.925743
# iteration 1800 / 2000: loss 1.861399
# iteration 1900 / 2000: loss 1.833948
# hidden_size=150, lr=0.000100, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.342000
# iteration 0 / 2000: loss 2.303260
# iteration 100 / 2000: loss 2.303217
# iteration 200 / 2000: loss 2.303148
# iteration 300 / 2000: loss 2.303077
# iteration 400 / 2000: loss 2.303008
# iteration 500 / 2000: loss 2.302863
# iteration 600 / 2000: loss 2.302579
# iteration 700 / 2000: loss 2.302576
# iteration 800 / 2000: loss 2.302454
# iteration 900 / 2000: loss 2.302456
# iteration 1000 / 2000: loss 2.302163
# iteration 1100 / 2000: loss 2.301679
# iteration 1200 / 2000: loss 2.301189
# iteration 1300 / 2000: loss 2.300876
# iteration 1400 / 2000: loss 2.301000
# iteration 1500 / 2000: loss 2.300404
# iteration 1600 / 2000: loss 2.298385
# iteration 1700 / 2000: loss 2.298206
# iteration 1800 / 2000: loss 2.298690
# iteration 1900 / 2000: loss 2.297629
# hidden_size=150, lr=0.000010, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.195000
# iteration 0 / 2000: loss 2.303799
# iteration 100 / 2000: loss 2.303716
# iteration 200 / 2000: loss 2.303620
# iteration 300 / 2000: loss 2.303571
# iteration 400 / 2000: loss 2.303476
# iteration 500 / 2000: loss 2.303376
# iteration 600 / 2000: loss 2.303375
# iteration 700 / 2000: loss 2.303129
# iteration 800 / 2000: loss 2.302888
# iteration 900 / 2000: loss 2.302915
# iteration 1000 / 2000: loss 2.302445
# iteration 1100 / 2000: loss 2.302388
# iteration 1200 / 2000: loss 2.302495
# iteration 1300 / 2000: loss 2.301597
# iteration 1400 / 2000: loss 2.301361
# iteration 1500 / 2000: loss 2.301832
# iteration 1600 / 2000: loss 2.299955
# iteration 1700 / 2000: loss 2.300429
# iteration 1800 / 2000: loss 2.299082
# iteration 1900 / 2000: loss 2.297043
# hidden_size=150, lr=0.000010, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.219000
# iteration 0 / 2000: loss 2.304459
# iteration 100 / 2000: loss 2.304406
# iteration 200 / 2000: loss 2.304292
# iteration 300 / 2000: loss 2.304247
# iteration 400 / 2000: loss 2.304144
# iteration 500 / 2000: loss 2.304059
# iteration 600 / 2000: loss 2.303915
# iteration 700 / 2000: loss 2.303810
# iteration 800 / 2000: loss 2.303632
# iteration 900 / 2000: loss 2.303556
# iteration 1000 / 2000: loss 2.303107
# iteration 1100 / 2000: loss 2.303024
# iteration 1200 / 2000: loss 2.302582
# iteration 1300 / 2000: loss 2.302132
# iteration 1400 / 2000: loss 2.302601
# iteration 1500 / 2000: loss 2.301251
# iteration 1600 / 2000: loss 2.299804
# iteration 1700 / 2000: loss 2.300250
# iteration 1800 / 2000: loss 2.298293
# iteration 1900 / 2000: loss 2.299580
# hidden_size=150, lr=0.000010, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.200000
# iteration 0 / 2000: loss 2.303265
# iteration 100 / 2000: loss 2.303225
# iteration 200 / 2000: loss 2.303151
# iteration 300 / 2000: loss 2.303094
# iteration 400 / 2000: loss 2.303003
# iteration 500 / 2000: loss 2.302917
# iteration 600 / 2000: loss 2.302867
# iteration 700 / 2000: loss 2.302828
# iteration 800 / 2000: loss 2.302509
# iteration 900 / 2000: loss 2.302638
# iteration 1000 / 2000: loss 2.302346
# iteration 1100 / 2000: loss 2.302141
# iteration 1200 / 2000: loss 2.302243
# iteration 1300 / 2000: loss 2.302224
# iteration 1400 / 2000: loss 2.301403
# iteration 1500 / 2000: loss 2.301824
# iteration 1600 / 2000: loss 2.302058
# iteration 1700 / 2000: loss 2.301594
# iteration 1800 / 2000: loss 2.300519
# iteration 1900 / 2000: loss 2.300462
# hidden_size=150, lr=0.000010, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.215000
# iteration 0 / 2000: loss 2.303720
# iteration 100 / 2000: loss 2.303647
# iteration 200 / 2000: loss 2.303585
# iteration 300 / 2000: loss 2.303507
# iteration 400 / 2000: loss 2.303461
# iteration 500 / 2000: loss 2.303375
# iteration 600 / 2000: loss 2.303394
# iteration 700 / 2000: loss 2.303299
# iteration 800 / 2000: loss 2.303208
# iteration 900 / 2000: loss 2.303092
# iteration 1000 / 2000: loss 2.302838
# iteration 1100 / 2000: loss 2.302879
# iteration 1200 / 2000: loss 2.302818
# iteration 1300 / 2000: loss 2.302470
# iteration 1400 / 2000: loss 2.302356
# iteration 1500 / 2000: loss 2.302104
# iteration 1600 / 2000: loss 2.302225
# iteration 1700 / 2000: loss 2.302352
# iteration 1800 / 2000: loss 2.301596
# iteration 1900 / 2000: loss 2.301313
# hidden_size=150, lr=0.000010, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.234000
# iteration 0 / 2000: loss 2.304457
# iteration 100 / 2000: loss 2.304425
# iteration 200 / 2000: loss 2.304369
# iteration 300 / 2000: loss 2.304235
# iteration 400 / 2000: loss 2.304219
# iteration 500 / 2000: loss 2.304203
# iteration 600 / 2000: loss 2.304037
# iteration 700 / 2000: loss 2.303978
# iteration 800 / 2000: loss 2.303914
# iteration 900 / 2000: loss 2.303658
# iteration 1000 / 2000: loss 2.303948
# iteration 1100 / 2000: loss 2.303382
# iteration 1200 / 2000: loss 2.303436
# iteration 1300 / 2000: loss 2.303367
# iteration 1400 / 2000: loss 2.303702
# iteration 1500 / 2000: loss 2.303328
# iteration 1600 / 2000: loss 2.302733
# iteration 1700 / 2000: loss 2.302766
# iteration 1800 / 2000: loss 2.302020
# iteration 1900 / 2000: loss 2.302266
# hidden_size=150, lr=0.000010, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.231000
# iteration 0 / 2000: loss 2.303583
# iteration 100 / 2000: loss 1.903140
# iteration 200 / 2000: loss 1.837480
# iteration 300 / 2000: loss 1.517073
# iteration 400 / 2000: loss 1.603477
# iteration 500 / 2000: loss 1.549583
# iteration 600 / 2000: loss 1.521140
# iteration 700 / 2000: loss 1.506103
# iteration 800 / 2000: loss 1.531159
# iteration 900 / 2000: loss 1.483771
# iteration 1000 / 2000: loss 1.480578
# iteration 1100 / 2000: loss 1.381620
# iteration 1200 / 2000: loss 1.352277
# iteration 1300 / 2000: loss 1.370399
# iteration 1400 / 2000: loss 1.297520
# iteration 1500 / 2000: loss 1.368128
# iteration 1600 / 2000: loss 1.290944
# iteration 1700 / 2000: loss 1.334033
# iteration 1800 / 2000: loss 1.208583
# iteration 1900 / 2000: loss 1.343408
# hidden_size=200, lr=0.001000, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.512000
# iteration 0 / 2000: loss 2.304128
# iteration 100 / 2000: loss 1.926779
# iteration 200 / 2000: loss 1.734756
# iteration 300 / 2000: loss 1.607462
# iteration 400 / 2000: loss 1.658769
# iteration 500 / 2000: loss 1.630331
# iteration 600 / 2000: loss 1.534462
# iteration 700 / 2000: loss 1.584847
# iteration 800 / 2000: loss 1.529529
# iteration 900 / 2000: loss 1.476816
# iteration 1000 / 2000: loss 1.483843
# iteration 1100 / 2000: loss 1.611188
# iteration 1200 / 2000: loss 1.315400
# iteration 1300 / 2000: loss 1.485791
# iteration 1400 / 2000: loss 1.479519
# iteration 1500 / 2000: loss 1.523676
# iteration 1600 / 2000: loss 1.430635
# iteration 1700 / 2000: loss 1.468193
# iteration 1800 / 2000: loss 1.314523
# iteration 1900 / 2000: loss 1.474279
# hidden_size=200, lr=0.001000, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.507000
# iteration 0 / 2000: loss 2.305031
# iteration 100 / 2000: loss 1.894496
# iteration 200 / 2000: loss 1.782748
# iteration 300 / 2000: loss 1.740562
# iteration 400 / 2000: loss 1.624643
# iteration 500 / 2000: loss 1.697377
# iteration 600 / 2000: loss 1.534812
# iteration 700 / 2000: loss 1.509000
# iteration 800 / 2000: loss 1.501725
# iteration 900 / 2000: loss 1.530639
# iteration 1000 / 2000: loss 1.482798
# iteration 1100 / 2000: loss 1.467312
# iteration 1200 / 2000: loss 1.563314
# iteration 1300 / 2000: loss 1.517732
# iteration 1400 / 2000: loss 1.445526
# iteration 1500 / 2000: loss 1.527562
# iteration 1600 / 2000: loss 1.564810
# iteration 1700 / 2000: loss 1.468704
# iteration 1800 / 2000: loss 1.478032
# iteration 1900 / 2000: loss 1.492637
# hidden_size=200, lr=0.001000, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.516000
# iteration 0 / 2000: loss 2.303518
# iteration 100 / 2000: loss 1.934654
# iteration 200 / 2000: loss 1.709921
# iteration 300 / 2000: loss 1.712415
# iteration 400 / 2000: loss 1.617014
# iteration 500 / 2000: loss 1.617848
# iteration 600 / 2000: loss 1.398395
# iteration 700 / 2000: loss 1.428468
# iteration 800 / 2000: loss 1.644025
# iteration 900 / 2000: loss 1.365050
# iteration 1000 / 2000: loss 1.420608
# iteration 1100 / 2000: loss 1.407704
# iteration 1200 / 2000: loss 1.440854
# iteration 1300 / 2000: loss 1.413971
# iteration 1400 / 2000: loss 1.248394
# iteration 1500 / 2000: loss 1.356043
# iteration 1600 / 2000: loss 1.436872
# iteration 1700 / 2000: loss 1.411079
# iteration 1800 / 2000: loss 1.310323
# iteration 1900 / 2000: loss 1.258315
# hidden_size=200, lr=0.001000, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.510000
# iteration 0 / 2000: loss 2.304099
# iteration 100 / 2000: loss 1.884225
# iteration 200 / 2000: loss 1.796106
# iteration 300 / 2000: loss 1.750761
# iteration 400 / 2000: loss 1.720883
# iteration 500 / 2000: loss 1.433835
# iteration 600 / 2000: loss 1.507224
# iteration 700 / 2000: loss 1.547136
# iteration 800 / 2000: loss 1.450097
# iteration 900 / 2000: loss 1.478398
# iteration 1000 / 2000: loss 1.547203
# iteration 1100 / 2000: loss 1.453323
# iteration 1200 / 2000: loss 1.533895
# iteration 1300 / 2000: loss 1.431674
# iteration 1400 / 2000: loss 1.523785
# iteration 1500 / 2000: loss 1.533586
# iteration 1600 / 2000: loss 1.340119
# iteration 1700 / 2000: loss 1.348449
# iteration 1800 / 2000: loss 1.271769
# iteration 1900 / 2000: loss 1.361420
# hidden_size=200, lr=0.001000, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.501000
# iteration 0 / 2000: loss 2.305025
# iteration 100 / 2000: loss 1.993575
# iteration 200 / 2000: loss 1.761028
# iteration 300 / 2000: loss 1.675213
# iteration 400 / 2000: loss 1.601314
# iteration 500 / 2000: loss 1.655612
# iteration 600 / 2000: loss 1.578490
# iteration 700 / 2000: loss 1.578928
# iteration 800 / 2000: loss 1.511171
# iteration 900 / 2000: loss 1.472444
# iteration 1000 / 2000: loss 1.502021
# iteration 1100 / 2000: loss 1.609726
# iteration 1200 / 2000: loss 1.560543
# iteration 1300 / 2000: loss 1.569850
# iteration 1400 / 2000: loss 1.483126
# iteration 1500 / 2000: loss 1.476619
# iteration 1600 / 2000: loss 1.376473
# iteration 1700 / 2000: loss 1.424898
# iteration 1800 / 2000: loss 1.460856
# iteration 1900 / 2000: loss 1.462397
# hidden_size=200, lr=0.001000, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.529000
# iteration 0 / 2000: loss 2.303525
# iteration 100 / 2000: loss 2.301348
# iteration 200 / 2000: loss 2.285801
# iteration 300 / 2000: loss 2.212334
# iteration 400 / 2000: loss 2.127095
# iteration 500 / 2000: loss 2.107929
# iteration 600 / 2000: loss 2.049033
# iteration 700 / 2000: loss 1.923736
# iteration 800 / 2000: loss 1.936104
# iteration 900 / 2000: loss 1.949712
# iteration 1000 / 2000: loss 1.953898
# iteration 1100 / 2000: loss 1.928218
# iteration 1200 / 2000: loss 1.891468
# iteration 1300 / 2000: loss 1.822574
# iteration 1400 / 2000: loss 1.826425
# iteration 1500 / 2000: loss 1.794973
# iteration 1600 / 2000: loss 1.796514
# iteration 1700 / 2000: loss 1.837399
# iteration 1800 / 2000: loss 1.750732
# iteration 1900 / 2000: loss 1.721918
# hidden_size=200, lr=0.000100, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.369000
# iteration 0 / 2000: loss 2.304158
# iteration 100 / 2000: loss 2.302757
# iteration 200 / 2000: loss 2.288001
# iteration 300 / 2000: loss 2.249026
# iteration 400 / 2000: loss 2.160094
# iteration 500 / 2000: loss 2.111225
# iteration 600 / 2000: loss 2.041454
# iteration 700 / 2000: loss 2.125514
# iteration 800 / 2000: loss 1.978142
# iteration 900 / 2000: loss 1.915393
# iteration 1000 / 2000: loss 1.972220
# iteration 1100 / 2000: loss 1.795423
# iteration 1200 / 2000: loss 1.867285
# iteration 1300 / 2000: loss 1.834886
# iteration 1400 / 2000: loss 1.804960
# iteration 1500 / 2000: loss 1.731894
# iteration 1600 / 2000: loss 1.805444
# iteration 1700 / 2000: loss 1.787200
# iteration 1800 / 2000: loss 1.816812
# iteration 1900 / 2000: loss 1.777187
# hidden_size=200, lr=0.000100, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.371000
# iteration 0 / 2000: loss 2.305081
# iteration 100 / 2000: loss 2.303345
# iteration 200 / 2000: loss 2.290757
# iteration 300 / 2000: loss 2.207109
# iteration 400 / 2000: loss 2.113389
# iteration 500 / 2000: loss 2.109516
# iteration 600 / 2000: loss 2.090585
# iteration 700 / 2000: loss 2.014067
# iteration 800 / 2000: loss 2.034005
# iteration 900 / 2000: loss 1.897059
# iteration 1000 / 2000: loss 1.887933
# iteration 1100 / 2000: loss 1.930755
# iteration 1200 / 2000: loss 1.843249
# iteration 1300 / 2000: loss 1.867546
# iteration 1400 / 2000: loss 1.869220
# iteration 1500 / 2000: loss 1.917568
# iteration 1600 / 2000: loss 1.804551
# iteration 1700 / 2000: loss 1.796769
# iteration 1800 / 2000: loss 1.856218
# iteration 1900 / 2000: loss 1.792122
# hidden_size=200, lr=0.000100, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.375000
# iteration 0 / 2000: loss 2.303550
# iteration 100 / 2000: loss 2.301796
# iteration 200 / 2000: loss 2.291946
# iteration 300 / 2000: loss 2.236512
# iteration 400 / 2000: loss 2.149120
# iteration 500 / 2000: loss 2.136275
# iteration 600 / 2000: loss 2.146741
# iteration 700 / 2000: loss 2.077354
# iteration 800 / 2000: loss 1.946534
# iteration 900 / 2000: loss 1.962555
# iteration 1000 / 2000: loss 1.850757
# iteration 1100 / 2000: loss 2.008182
# iteration 1200 / 2000: loss 1.928031
# iteration 1300 / 2000: loss 1.875213
# iteration 1400 / 2000: loss 1.846875
# iteration 1500 / 2000: loss 1.856598
# iteration 1600 / 2000: loss 1.843523
# iteration 1700 / 2000: loss 1.867852
# iteration 1800 / 2000: loss 1.911169
# iteration 1900 / 2000: loss 1.920813
# hidden_size=200, lr=0.000100, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.352000
# iteration 0 / 2000: loss 2.304075
# iteration 100 / 2000: loss 2.302384
# iteration 200 / 2000: loss 2.290573
# iteration 300 / 2000: loss 2.247638
# iteration 400 / 2000: loss 2.161642
# iteration 500 / 2000: loss 2.067537
# iteration 600 / 2000: loss 2.029248
# iteration 700 / 2000: loss 2.084583
# iteration 800 / 2000: loss 1.985914
# iteration 900 / 2000: loss 1.959187
# iteration 1000 / 2000: loss 1.910450
# iteration 1100 / 2000: loss 1.978990
# iteration 1200 / 2000: loss 1.956702
# iteration 1300 / 2000: loss 1.929244
# iteration 1400 / 2000: loss 1.872788
# iteration 1500 / 2000: loss 1.832911
# iteration 1600 / 2000: loss 1.915579
# iteration 1700 / 2000: loss 1.802604
# iteration 1800 / 2000: loss 1.743262
# iteration 1900 / 2000: loss 1.791619
# hidden_size=200, lr=0.000100, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.348000
# iteration 0 / 2000: loss 2.305022
# iteration 100 / 2000: loss 2.303383
# iteration 200 / 2000: loss 2.285979
# iteration 300 / 2000: loss 2.252391
# iteration 400 / 2000: loss 2.205384
# iteration 500 / 2000: loss 2.117447
# iteration 600 / 2000: loss 2.065441
# iteration 700 / 2000: loss 1.967380
# iteration 800 / 2000: loss 1.995364
# iteration 900 / 2000: loss 1.947921
# iteration 1000 / 2000: loss 1.980961
# iteration 1100 / 2000: loss 1.895434
# iteration 1200 / 2000: loss 1.930018
# iteration 1300 / 2000: loss 1.822780
# iteration 1400 / 2000: loss 1.978885
# iteration 1500 / 2000: loss 1.805526
# iteration 1600 / 2000: loss 1.900424
# iteration 1700 / 2000: loss 1.828887
# iteration 1800 / 2000: loss 1.849366
# iteration 1900 / 2000: loss 1.890829
# hidden_size=200, lr=0.000100, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.346000
# iteration 0 / 2000: loss 2.303528
# iteration 100 / 2000: loss 2.303405
# iteration 200 / 2000: loss 2.303371
# iteration 300 / 2000: loss 2.303186
# iteration 400 / 2000: loss 2.303094
# iteration 500 / 2000: loss 2.302955
# iteration 600 / 2000: loss 2.302765
# iteration 700 / 2000: loss 2.302929
# iteration 800 / 2000: loss 2.302459
# iteration 900 / 2000: loss 2.302303
# iteration 1000 / 2000: loss 2.302187
# iteration 1100 / 2000: loss 2.301346
# iteration 1200 / 2000: loss 2.300947
# iteration 1300 / 2000: loss 2.300619
# iteration 1400 / 2000: loss 2.300223
# iteration 1500 / 2000: loss 2.300271
# iteration 1600 / 2000: loss 2.299061
# iteration 1700 / 2000: loss 2.298417
# iteration 1800 / 2000: loss 2.298432
# iteration 1900 / 2000: loss 2.295794
# hidden_size=200, lr=0.000010, lr_deacy=0.950000, reg=0.150000,Validation accuracy=0.189000
# iteration 0 / 2000: loss 2.304170
# iteration 100 / 2000: loss 2.304066
# iteration 200 / 2000: loss 2.303954
# iteration 300 / 2000: loss 2.303815
# iteration 400 / 2000: loss 2.303712
# iteration 500 / 2000: loss 2.303637
# iteration 600 / 2000: loss 2.303537
# iteration 700 / 2000: loss 2.303229
# iteration 800 / 2000: loss 2.303092
# iteration 900 / 2000: loss 2.303163
# iteration 1000 / 2000: loss 2.302898
# iteration 1100 / 2000: loss 2.302774
# iteration 1200 / 2000: loss 2.302208
# iteration 1300 / 2000: loss 2.302293
# iteration 1400 / 2000: loss 2.302074
# iteration 1500 / 2000: loss 2.300685
# iteration 1600 / 2000: loss 2.300101
# iteration 1700 / 2000: loss 2.299371
# iteration 1800 / 2000: loss 2.299334
# iteration 1900 / 2000: loss 2.298399
# hidden_size=200, lr=0.000010, lr_deacy=0.950000, reg=0.250000,Validation accuracy=0.213000
# iteration 0 / 2000: loss 2.305037
# iteration 100 / 2000: loss 2.304969
# iteration 200 / 2000: loss 2.304840
# iteration 300 / 2000: loss 2.304696
# iteration 400 / 2000: loss 2.304685
# iteration 500 / 2000: loss 2.304600
# iteration 600 / 2000: loss 2.304400
# iteration 700 / 2000: loss 2.304369
# iteration 800 / 2000: loss 2.303839
# iteration 900 / 2000: loss 2.303767
# iteration 1000 / 2000: loss 2.303484
# iteration 1100 / 2000: loss 2.303205
# iteration 1200 / 2000: loss 2.302833
# iteration 1300 / 2000: loss 2.302618
# iteration 1400 / 2000: loss 2.300980
# iteration 1500 / 2000: loss 2.300456
# iteration 1600 / 2000: loss 2.300272
# iteration 1700 / 2000: loss 2.299044
# iteration 1800 / 2000: loss 2.297051
# iteration 1900 / 2000: loss 2.299092
# hidden_size=200, lr=0.000010, lr_deacy=0.950000, reg=0.400000,Validation accuracy=0.228000
# iteration 0 / 2000: loss 2.303442
# iteration 100 / 2000: loss 2.303465
# iteration 200 / 2000: loss 2.303286
# iteration 300 / 2000: loss 2.303280
# iteration 400 / 2000: loss 2.303139
# iteration 500 / 2000: loss 2.303068
# iteration 600 / 2000: loss 2.302794
# iteration 700 / 2000: loss 2.302853
# iteration 800 / 2000: loss 2.302461
# iteration 900 / 2000: loss 2.302405
# iteration 1000 / 2000: loss 2.302390
# iteration 1100 / 2000: loss 2.301936
# iteration 1200 / 2000: loss 2.302496
# iteration 1300 / 2000: loss 2.301184
# iteration 1400 / 2000: loss 2.301040
# iteration 1500 / 2000: loss 2.300694
# iteration 1600 / 2000: loss 2.301112
# iteration 1700 / 2000: loss 2.299985
# iteration 1800 / 2000: loss 2.299569
# iteration 1900 / 2000: loss 2.300007
# hidden_size=200, lr=0.000010, lr_deacy=0.900000, reg=0.150000,Validation accuracy=0.218000
# iteration 0 / 2000: loss 2.304135
# iteration 100 / 2000: loss 2.304002
# iteration 200 / 2000: loss 2.303924
# iteration 300 / 2000: loss 2.303952
# iteration 400 / 2000: loss 2.303807
# iteration 500 / 2000: loss 2.303737
# iteration 600 / 2000: loss 2.303709
# iteration 700 / 2000: loss 2.303461
# iteration 800 / 2000: loss 2.303435
# iteration 900 / 2000: loss 2.303033
# iteration 1000 / 2000: loss 2.302823
# iteration 1100 / 2000: loss 2.302927
# iteration 1200 / 2000: loss 2.302603
# iteration 1300 / 2000: loss 2.302150
# iteration 1400 / 2000: loss 2.302475
# iteration 1500 / 2000: loss 2.301668
# iteration 1600 / 2000: loss 2.301380
# iteration 1700 / 2000: loss 2.301492
# iteration 1800 / 2000: loss 2.301066
# iteration 1900 / 2000: loss 2.300395
# hidden_size=200, lr=0.000010, lr_deacy=0.900000, reg=0.250000,Validation accuracy=0.217000
# iteration 0 / 2000: loss 2.305075
# iteration 100 / 2000: loss 2.304979
# iteration 200 / 2000: loss 2.304907
# iteration 300 / 2000: loss 2.304782
# iteration 400 / 2000: loss 2.304741
# iteration 500 / 2000: loss 2.304614
# iteration 600 / 2000: loss 2.304520
# iteration 700 / 2000: loss 2.304485
# iteration 800 / 2000: loss 2.304210
# iteration 900 / 2000: loss 2.304071
# iteration 1000 / 2000: loss 2.304082
# iteration 1100 / 2000: loss 2.303856
# iteration 1200 / 2000: loss 2.303566
# iteration 1300 / 2000: loss 2.303497
# iteration 1400 / 2000: loss 2.303613
# iteration 1500 / 2000: loss 2.303509
# iteration 1600 / 2000: loss 2.302645
# iteration 1700 / 2000: loss 2.302361
# iteration 1800 / 2000: loss 2.302178
# iteration 1900 / 2000: loss 2.302376
# hidden_size=200, lr=0.000010, lr_deacy=0.900000, reg=0.400000,Validation accuracy=0.211000
# best_acc=0.529000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.537

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$1,3
#
# $\color{blue}{\textit Your Explanation:}$泛化能力不行，可能是过拟合，增大数据，增强正则化都可以达到
